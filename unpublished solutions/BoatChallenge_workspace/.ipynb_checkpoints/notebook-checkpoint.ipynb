# %% [markdown]
# # Data Scientist Professional Practical Exam
#
# ### Company Background
#
# Nearly New Nautical is a website that allows users to advertise their used boats for sale. When users list their boat, they have to provide a range of information about their boat. Boats that get lots of views bring more traffic to the website, and more potential customers.
#
# To boost traffic to the website, the product manager wants to prevent listing boats that do not receive many views.
#
#
#
#
# ### Customer Question
#
# The product manager wants to know the following:
# - Can you predict the number of views a listing will receive based on the boat's features?
#
#
#
# ### Success Criteria
#
# The product manager would consider using your model if, on average, the predictions were only 50% off of the true number of views a listing would receive.
#
#
# ### Dataset
#
# The data you will use for this analysis can be accessed here: `"data/boat_data.csv"`

# %% [markdown]
# # Install and Import Modules

# %%
# Install modules not preinstalled in DC Workspaces
# !pip install dataprep
# !pip install forex_python
# !pip install ftfy
# !pip install missingpy
# Out:
# Collecting dataprep
#   Using cached dataprep-0.4.5-py3-none-any.whl (9.9 MB)
# Collecting flask_cors<4.0.0,>=3.0.10
#   Using cached Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting regex<2022.0.0,>=2021.8.3
#   Using cached regex-2021.11.10-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (764 kB)
# Collecting pandas<2.0,>=1.1
#   Using cached pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
# Collecting scipy<2.0,>=1.8
#   Using cached scipy-1.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# Collecting jinja2<3.1,>=3.0
#   Using cached Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting dask[array,dataframe,delayed]>=2022.3.0
#   Using cached dask-2022.12.1-py3-none-any.whl (1.1 MB)
# Collecting flask<3,>=2
#   Using cached Flask-2.2.2-py3-none-any.whl (101 kB)
# Collecting jsonpath-ng<2.0,>=1.5
#   Using cached jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting sqlalchemy==1.3.24
#   Using cached SQLAlchemy-1.3.24-cp38-cp38-manylinux2010_x86_64.whl (1.3 MB)
# Collecting nltk<4.0.0,>=3.6.7
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting ipywidgets<8.0,>=7.5
#   Using cached ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
# Collecting varname<0.9.0,>=0.8.1
#   Using cached varname-0.8.3-py3-none-any.whl (21 kB)
# Collecting metaphone<0.7,>=0.6
#   Using cached Metaphone-0.6-py3-none-any.whl
# Collecting wordcloud<2.0,>=1.8
#   Using cached wordcloud-1.8.2.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
# Collecting pydantic<2.0,>=1.6
#   Using cached pydantic-1.10.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting aiohttp<4.0,>=3.6
#   Using cached aiohttp-3.8.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Collecting bokeh<3,>=2
#   Using cached bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Collecting python-stdnum<2.0,>=1.16
#   Using cached python_stdnum-1.18-py2.py3-none-any.whl (1.0 MB)
# Collecting rapidfuzz<3.0.0,>=2.1.2
#   Using cached rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
# Collecting pydot<2.0.0,>=1.4.2
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting tqdm<5.0,>=4.48
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting python-crfsuite==0.9.8
#   Using cached python_crfsuite-0.9.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Collecting numpy<2.0,>=1.21
#   Using cached numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Collecting charset-normalizer<3.0,>=2.0
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-22.2.0-py3-none-any.whl (60 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.8.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (262 kB)
# Collecting typing-extensions>=3.10.0
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting packaging>=16.8
#   Using cached packaging-23.0-py3-none-any.whl (42 kB)
# Collecting pillow>=7.1.0
#   Using cached Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting tornado>=5.1
#   Using cached tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
# Collecting PyYAML>=3.10
#   Using cached PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# Collecting toolz>=0.8.2
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting fsspec>=0.6.0
#   Using cached fsspec-2022.11.0-py3-none-any.whl (139 kB)
# Collecting click>=7.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting cloudpickle>=1.1.1
#   Using cached cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting partd>=0.3.10
#   Using cached partd-1.3.0-py3-none-any.whl (18 kB)
# Collecting importlib-metadata>=3.6.0
#   Using cached importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting itsdangerous>=2.0
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting Werkzeug>=2.2.2
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting Six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting traitlets>=4.3.1
#   Using cached traitlets-5.8.1-py3-none-any.whl (116 kB)
# Collecting ipython>=4.0.0
#   Using cached ipython-8.8.0-py3-none-any.whl (775 kB)
# Collecting ipykernel>=4.5.1
#   Using cached ipykernel-6.20.1-py3-none-any.whl (149 kB)
# Collecting ipython-genutils~=0.2.0
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Using cached jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
# Collecting widgetsnbextension~=3.6.0
#   Using cached widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting decorator
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting ply
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.7-py2.py3-none-any.whl (499 kB)
# Collecting python-dateutil>=2.8.1
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pyparsing>=2.1.4
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting pure_eval<1.0.0
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting executing<0.9.0,>=0.8.3
#   Using cached executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Collecting asttokens<3.0.0,>=2.0.0
#   Using cached asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.6.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
# Collecting zipp>=0.5
#   Using cached zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Collecting nest-asyncio
#   Using cached nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting comm>=0.1.1
#   Using cached comm-0.1.2-py3-none-any.whl (6.5 kB)
# Collecting jupyter-client>=6.1.12
#   Using cached jupyter_client-7.4.8-py3-none-any.whl (133 kB)
# Collecting psutil
#   Using cached psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# Collecting debugpy>=1.0
#   Using cached debugpy-1.6.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting pyzmq>=17
#   Using cached pyzmq-24.0.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Collecting matplotlib-inline>=0.1
#   Using cached matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting pygments>=2.4.0
#   Using cached Pygments-2.14.0-py3-none-any.whl (1.1 MB)
# Collecting pickleshare
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting pexpect>4.3
#   Using cached pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.11
#   Using cached prompt_toolkit-3.0.36-py3-none-any.whl (386 kB)
# Collecting jedi>=0.16
#   Using cached jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
# Collecting backcall
#   Using cached backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting stack-data
#   Using cached stack_data-0.6.2-py3-none-any.whl (24 kB)
# Collecting locket
#   Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting notebook>=4.4.1
#   Using cached notebook-6.5.2-py3-none-any.whl (439 kB)
# Collecting idna>=2.0
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (295 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Collecting parso<0.9.0,>=0.8.0
#   Using cached parso-0.8.3-py2.py3-none-any.whl (100 kB)
# Collecting entrypoints
#   Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting jupyter-core>=4.9.2
#   Using cached jupyter_core-5.1.3-py3-none-any.whl (93 kB)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.15.0-py3-none-any.whl (60 kB)
# Collecting nbclassic>=0.4.7
#   Using cached nbclassic-0.4.8-py3-none-any.whl (9.8 MB)
# Collecting nbconvert>=5
#   Using cached nbconvert-7.2.7-py3-none-any.whl (273 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting nbformat
#   Using cached nbformat-5.7.2-py3-none-any.whl (78 kB)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting ptyprocess>=0.5
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Using cached wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting stack-data
#   Using cached stack_data-0.6.1-py3-none-any.whl (24 kB)
#   Using cached stack_data-0.6.0-py3-none-any.whl (24 kB)
#   Using cached stack_data-0.5.1-py3-none-any.whl (24 kB)
# Collecting platformdirs>=2.5
#   Using cached platformdirs-2.6.2-py3-none-any.whl (14 kB)
# Collecting notebook-shim>=0.1.0
#   Using cached notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting jupyter-server>=1.8
#   Using cached jupyter_server-2.0.6-py3-none-any.whl (363 kB)
# Collecting mistune<3,>=2.0.3
#   Using cached mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting bleach
#   Using cached bleach-5.0.1-py3-none-any.whl (160 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.7.2-py3-none-any.whl (71 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting fastjsonschema
#   Using cached fastjsonschema-2.16.2-py3-none-any.whl (22 kB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Collecting pkgutil-resolve-name>=1.3.10
#   Using cached pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Using cached pyrsistent-0.19.3-py3-none-any.whl (57 kB)
# Collecting importlib-resources>=1.4.0
#   Using cached importlib_resources-5.10.2-py3-none-any.whl (34 kB)
# Collecting jupyter-events>=0.4.0
#   Using cached jupyter_events-0.6.2-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting websocket-client
#   Using cached websocket_client-1.4.2-py3-none-any.whl (55 kB)
# Collecting anyio<4,>=3.1.0
#   Using cached anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-2.0.4-py3-none-any.whl (7.8 kB)
# Collecting uri-template
#   Using cached uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting webcolors>=1.11
#   Using cached webcolors-1.12-py3-none-any.whl (9.9 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Installing collected packages: webencodings, wcwidth, Send2Trash, regex, pytz, python-stdnum, python-crfsuite, pure_eval, ptyprocess, ply, pickleshare, mistune, metaphone, ipython-genutils, fastjsonschema, executing, backcall, zipp, websocket-client, webcolors, uri-template, typing-extensions, traitlets, tqdm, tornado, toolz, tinycss2, sqlalchemy, soupsieve, sniffio, Six, rfc3986-validator, rapidfuzz, pyzmq, PyYAML, python-json-logger, pyrsistent, pyparsing, pygments, pycparser, psutil, prompt-toolkit, prometheus-client, platformdirs, pkgutil-resolve-name, pillow, pexpect, parso, pandocfilters, packaging, numpy, nest-asyncio, multidict, MarkupSafe, locket, kiwisolver, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, joblib, itsdangerous, idna, fsspec, frozenlist, fqdn, fonttools, entrypoints, defusedxml, decorator, debugpy, cycler, cloudpickle, click, charset-normalizer, attrs, async-timeout, yarl, Werkzeug, terminado, scipy, rfc3339-validator, python-dateutil, pydot, pydantic, partd, nltk, matplotlib-inline, jupyter-core, jsonpath-ng, jinja2, jedi, importlib-resources, importlib-metadata, contourpy, comm, cffi, bleach, beautifulsoup4, asttokens, anyio, aiosignal, varname, stack-data, pandas, matplotlib, jupyter-server-terminals, jupyter-client, jsonschema, flask, dask, bokeh, arrow, argon2-cffi-bindings, aiohttp, wordcloud, nbformat, isoduration, ipython, flask_cors, argon2-cffi, nbclient, ipykernel, nbconvert, jupyter-events, jupyter-server, notebook-shim, nbclassic, notebook, widgetsnbextension, ipywidgets, dataprep
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# redshift-connector 2.0.908 requires pytz<2022.2,>=2020.1, but you have pytz 2022.7 which is incompatible.
# redshift-connector 2.0.908 requires requests<2.28.1,>=2.23.0, but you have requests 2.28.1 which is incompatible.
# pandas-profiling 3.4.0 requires matplotlib<3.6,>=3.2, but you have matplotlib 3.6.2 which is incompatible.
# pandas-profiling 3.4.0 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.1 which is incompatible.
# pandas-profiling 3.4.0 requires scipy<1.10,>=1.4.1, but you have scipy 1.10.0 which is incompatible.
# mlflow 2.0.1 requires importlib-metadata!=4.7.0,<6,>=3.7.0, but you have importlib-metadata 6.0.0 which is incompatible.
# mlflow 2.0.1 requires packaging<22, but you have packaging 23.0 which is incompatible.
# mlflow 2.0.1 requires sqlalchemy<2,>=1.4.0, but you have sqlalchemy 1.3.24 which is incompatible.
# markdown-it-py 1.1.0 requires attrs<22,>=19, but you have attrs 22.2.0 which is incompatible.
# jsonrpcserver 5.0.5 requires jsonschema<4, but you have jsonschema 4.17.3 which is incompatible.
# gremlinpython 3.6.1 requires aiohttp<=3.8.1,>=3.8.0, but you have aiohttp 3.8.3 which is incompatible.
# bertopic 0.12.0 requires pyyaml<6.0, but you have pyyaml 6.0 which is incompatible.
# awscli 1.25.61 requires PyYAML<5.5,>=3.10, but you have pyyaml 6.0 which is incompatible.
# pythonwhat 2.23.1 requires asttokens~=1.1.10, but you have asttokens 2.2.1 which is incompatible.
# pythonwhat 2.23.1 requires dill~=0.2.7.1, but you have dill 0.3.5.1 which is incompatible.
# pythonwhat 2.23.1 requires jinja2~=2.10, but you have jinja2 3.0.3 which is incompatible.
# protowhat 2.0.1 requires jinja2~=2.10, but you have jinja2 3.0.3 which is incompatible.
# Successfully installed MarkupSafe-2.1.1 PyYAML-6.0 Send2Trash-1.8.0 Six-1.16.0 Werkzeug-2.2.2 aiohttp-3.8.3 aiosignal-1.3.1 anyio-3.6.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 asttokens-2.2.1 async-timeout-4.0.2 attrs-22.2.0 backcall-0.2.0 beautifulsoup4-4.11.1 bleach-5.0.1 bokeh-2.4.3 cffi-1.15.1 charset-normalizer-2.1.1 click-8.1.3 cloudpickle-2.2.0 comm-0.1.2 contourpy-1.0.6 cycler-0.11.0 dask-2022.12.1 dataprep-0.4.5 debugpy-1.6.5 decorator-5.1.1 defusedxml-0.7.1 entrypoints-0.4 executing-0.8.3 fastjsonschema-2.16.2 flask-2.2.2 flask_cors-3.0.10 fonttools-4.38.0 fqdn-1.5.1 frozenlist-1.3.3 fsspec-2022.11.0 idna-3.4 importlib-metadata-6.0.0 importlib-resources-5.10.2 ipykernel-6.20.1 ipython-8.8.0 ipython-genutils-0.2.0 ipywidgets-7.7.2 isoduration-20.11.0 itsdangerous-2.1.2 jedi-0.18.2 jinja2-3.0.3 joblib-1.2.0 jsonpath-ng-1.5.3 jsonpointer-2.3 jsonschema-4.17.3 jupyter-client-7.4.8 jupyter-core-5.1.3 jupyter-events-0.6.2 jupyter-server-2.0.6 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 jupyterlab-widgets-1.1.1 kiwisolver-1.4.4 locket-1.0.0 matplotlib-3.6.2 matplotlib-inline-0.1.6 metaphone-0.6 mistune-2.0.4 multidict-6.0.4 nbclassic-0.4.8 nbclient-0.7.2 nbconvert-7.2.7 nbformat-5.7.2 nest-asyncio-1.5.6 nltk-3.8.1 notebook-6.5.2 notebook-shim-0.2.2 numpy-1.24.1 packaging-23.0 pandas-1.5.2 pandocfilters-1.5.0 parso-0.8.3 partd-1.3.0 pexpect-4.8.0 pickleshare-0.7.5 pillow-9.4.0 pkgutil-resolve-name-1.3.10 platformdirs-2.6.2 ply-3.11 prometheus-client-0.15.0 prompt-toolkit-3.0.36 psutil-5.9.4 ptyprocess-0.7.0 pure_eval-0.2.2 pycparser-2.21 pydantic-1.10.4 pydot-1.4.2 pygments-2.14.0 pyparsing-3.0.9 pyrsistent-0.19.3 python-crfsuite-0.9.8 python-dateutil-2.8.2 python-json-logger-2.0.4 python-stdnum-1.18 pytz-2022.7 pyzmq-24.0.1 rapidfuzz-2.13.7 regex-2021.11.10 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 scipy-1.10.0 sniffio-1.3.0 soupsieve-2.3.2.post1 sqlalchemy-1.3.24 stack-data-0.5.1 terminado-0.17.1 tinycss2-1.2.1 toolz-0.12.0 tornado-6.2 tqdm-4.64.1 traitlets-5.8.1 typing-extensions-4.4.0 uri-template-1.2.0 varname-0.8.3 wcwidth-0.2.5 webcolors-1.12 webencodings-0.5.1 websocket-client-1.4.2 widgetsnbextension-3.6.1 wordcloud-1.8.2.2 yarl-1.8.2 zipp-3.11.0
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/webencodings already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/webencodings-0.5.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/wcwidth already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/wcwidth-0.2.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/send2trash already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Send2Trash-1.8.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/regex already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/regex-2021.11.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pytz already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pytz-2022.7.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/stdnum already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/python_stdnum-1.18.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pycrfsuite already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/python_crfsuite-0.9.8.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pure_eval already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pure_eval-0.2.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ptyprocess already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ptyprocess-0.7.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ply already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ply-3.11.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pickleshare.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pickleshare-0.7.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/mistune already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/mistune-2.0.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/metaphone already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Metaphone-0.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ipython_genutils already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ipython_genutils-0.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/fastjsonschema already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/fastjsonschema-2.16.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/executing already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/executing-0.8.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/backcall already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/backcall-0.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/zipp already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/zipp-3.11.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/websocket already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/websocket_client-1.4.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/webcolors.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/webcolors-1.12.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/uri_template already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/uri_template-1.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/typing_extensions.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/typing_extensions-4.4.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/traitlets already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/traitlets-5.8.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/tqdm already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/tqdm-4.64.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/tornado already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/tornado-6.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/tlz already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/toolz already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/toolz-0.12.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/tinycss2 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/tinycss2-1.2.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/sqlalchemy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/SQLAlchemy-1.3.24.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/soupsieve already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/soupsieve-2.3.2.post1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/sniffio already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/sniffio-1.3.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/six-1.16.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/rfc3986_validator.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/rfc3986_validator-0.1.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/rapidfuzz already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/rapidfuzz-2.13.7.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pyzmq-24.0.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pyzmq.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/zmq already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/PyYAML-6.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/_yaml already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/yaml already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pythonjsonlogger already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/python_json_logger-2.0.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/_pyrsistent_version.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pyrsistent already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pyrsistent-0.19.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pyparsing already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pyparsing-3.0.9.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pygments already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Pygments-2.14.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pycparser already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pycparser-2.21.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/psutil already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/psutil-5.9.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/prompt_toolkit already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/prompt_toolkit-3.0.36.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/prometheus_client already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/prometheus_client-0.15.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/platformdirs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/platformdirs-2.6.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pkgutil_resolve_name.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pkgutil_resolve_name-1.3.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Pillow-9.4.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Pillow.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/PIL already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pexpect already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pexpect-4.8.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/parso already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/parso-0.8.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pandocfilters.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pandocfilters-1.5.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/packaging already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/packaging-23.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/numpy-1.24.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nest_asyncio.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nest_asyncio-1.5.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/multidict already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/multidict-6.0.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/MarkupSafe-2.1.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/markupsafe already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/locket already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/locket-1.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/kiwisolver already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/kiwisolver-1.4.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyterlab_widgets already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyterlab_widgets-1.1.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyterlab_pygments already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyterlab_pygments-0.2.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jsonpointer.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jsonpointer-2.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/joblib already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/joblib-1.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/itsdangerous already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/itsdangerous-2.1.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/idna already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/idna-3.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/fsspec already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/fsspec-2022.11.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/frozenlist already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/frozenlist-1.3.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/fqdn already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/fqdn-1.5.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/fontTools already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/fonttools-4.38.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/entrypoints.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/entrypoints-0.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/defusedxml already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/defusedxml-0.7.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/decorator.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/decorator-5.1.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/debugpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/debugpy-1.6.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/cycler.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/cycler-0.11.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/cloudpickle already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/cloudpickle-2.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/click already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/click-8.1.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/charset_normalizer already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/charset_normalizer-2.1.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/attr already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/attrs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/attrs-22.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/async_timeout already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/async_timeout-4.0.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/yarl-1.8.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/yarl already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/werkzeug already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Werkzeug-2.2.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/terminado already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/terminado-0.17.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/scipy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/scipy-1.10.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/scipy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/rfc3339_validator.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/rfc3339_validator-0.1.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/dateutil already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/python_dateutil-2.8.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/dot_parser.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pydot.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pydot-1.4.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pydantic already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pydantic-1.10.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/partd already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/partd-1.3.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nltk already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nltk-3.8.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/matplotlib_inline already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/matplotlib_inline-0.1.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_core already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_core-5.1.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jsonpath_ng already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jsonpath_ng-1.5.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jinja2 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Jinja2-3.0.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jedi already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jedi-0.18.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/importlib_resources already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/importlib_resources-5.10.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/importlib_metadata already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/importlib_metadata-6.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/contourpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/contourpy-1.0.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/comm already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/comm-0.1.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/_cffi_backend.cpython-38-x86_64-linux-gnu.so already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/cffi-1.15.1.dist-info already exists. Specify --upgrade to force replacement.
# ...
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/varname-0.8.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/stack_data already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/stack_data-0.5.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pandas already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pandas-1.5.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/matplotlib-3.6.2-py3.8-nspkg.pth already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/pylab.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/matplotlib-3.6.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/mpl_toolkits already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/matplotlib already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_server_terminals already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_server_terminals-0.4.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_client already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_client-7.4.8.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jsonschema already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jsonschema-4.17.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/flask already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Flask-2.2.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/dask already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/dask-2022.12.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/bokeh already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/bokeh-2.4.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/arrow already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/arrow-1.2.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/argon2_cffi_bindings-21.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/_argon2_cffi_bindings already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/aiohttp-3.8.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/aiohttp already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/wordcloud-1.8.2.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/wordcloud already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nbformat already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nbformat-5.7.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/isoduration already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/isoduration-20.11.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/IPython already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ipython-8.8.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/flask_cors already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/Flask_Cors-3.0.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/argon2 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/argon2_cffi-21.3.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nbclient already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nbclient-0.7.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ipykernel already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ipykernel_launcher.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ipykernel-6.20.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nbconvert already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nbconvert-7.2.7.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_events already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_events-0.6.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_server already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/jupyter_server-2.0.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/notebook_shim already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/notebook_shim-0.2.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nbclassic already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/nbclassic-0.4.8.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/notebook already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/notebook-6.5.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/widgetsnbextension already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/widgetsnbextension-3.6.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ipywidgets already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ipywidgets-7.7.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/dataprep already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/dataprep-0.4.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/bin already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/share already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/etc already exists. Specify --upgrade to force replacement.
# Collecting forex_python
#   Using cached forex_python-1.8-py3-none-any.whl (8.2 kB)
# Collecting simplejson
#   Using cached simplejson-3.18.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Installing collected packages: urllib3, simplejson, idna, charset-normalizer, certifi, requests, forex_python
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# redshift-connector 2.0.908 requires pytz<2022.2,>=2020.1, but you have pytz 2022.7 which is incompatible.
# redshift-connector 2.0.908 requires requests<2.28.1,>=2.23.0, but you have requests 2.28.1 which is incompatible.
# pandas-profiling 3.4.0 requires matplotlib<3.6,>=3.2, but you have matplotlib 3.6.2 which is incompatible.
# pandas-profiling 3.4.0 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.1 which is incompatible.
# pandas-profiling 3.4.0 requires scipy<1.10,>=1.4.1, but you have scipy 1.10.0 which is incompatible.
# mlflow 2.0.1 requires importlib-metadata!=4.7.0,<6,>=3.7.0, but you have importlib-metadata 6.0.0 which is incompatible.
# mlflow 2.0.1 requires packaging<22, but you have packaging 23.0 which is incompatible.
# mlflow 2.0.1 requires sqlalchemy<2,>=1.4.0, but you have sqlalchemy 1.3.24 which is incompatible.
# gremlinpython 3.6.1 requires aiohttp<=3.8.1,>=3.8.0, but you have aiohttp 3.8.3 which is incompatible.
# bertopic 0.12.0 requires pyyaml<6.0, but you have pyyaml 6.0 which is incompatible.
# awscli 1.25.61 requires PyYAML<5.5,>=3.10, but you have pyyaml 6.0 which is incompatible.
# Successfully installed certifi-2022.12.7 charset-normalizer-2.1.1 forex_python-1.8 idna-3.4 requests-2.28.1 simplejson-3.18.1 urllib3-1.26.14
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/urllib3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/urllib3-1.26.14.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/simplejson already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/simplejson-3.18.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/idna already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/idna-3.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/charset_normalizer already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/charset_normalizer-2.1.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/certifi already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/certifi-2022.12.7.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/requests already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/requests-2.28.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/docs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/forex_python already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/forex_python-1.8.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/bin already exists. Specify --upgrade to force replacement.
# Collecting ftfy
#   Using cached ftfy-6.1.1-py3-none-any.whl (53 kB)
# Collecting wcwidth>=0.2.5
#   Using cached wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Installing collected packages: wcwidth, ftfy
# Successfully installed ftfy-6.1.1 wcwidth-0.2.5
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/wcwidth already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/wcwidth-0.2.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/CHANGELOG.md already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/README.md already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ftfy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/ftfy-6.1.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/bin already exists. Specify --upgrade to force replacement.
# Collecting missingpy
#   Using cached missingpy-0.2.0-py3-none-any.whl (49 kB)
# Installing collected packages: missingpy
# Successfully installed missingpy-0.2.0
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/missingpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/missingpy-0.2.0.dist-info already exists. Specify --upgrade to force replacement.

# %%
# Import modules
import pandas as pd
import numpy as np
import statsmodels as sm
import datetime as dt
import chardet as ch 
import missingno as msno
import random as rnd

from geopy import geocoders
from geopy.extra.rate_limiter import RateLimiter
from functools import partial
from scipy import stats

from forex_python.converter import CurrencyRates
from ftfy import fix_and_explain, fix_text
from dataprep import clean

import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, PowerTransformer, OrdinalEncoder
from sklearn.metrics import r2_score,mean_squared_error

from sklearn.linear_model import BayesianRidge, Ridge, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

plt.style.use('ggplot')
sns.set_context("notebook")
rnd.seed(42)
np.random.RandomState(42)
# Out:
# RandomState(MT19937) at 0x7F262053E640

# %% [markdown]
# # Load Data

# %%
with open('data/boat_data.csv', 'rb') as file:             # check CSV file encoding to reduce reding errors and data cleanup
    print(ch.detect(file.read()))
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
df = pd.read_csv('data/boat_data.csv', encoding = "utf-8")     # load data into dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9888 entries, 0 to 9887
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Price                        9888 non-null   object
#  1   Boat Type                    9888 non-null   object
#  2   Manufacturer                 8550 non-null   object
#  3   Type                         9882 non-null   object
#  4   Year Built                   9888 non-null   int64
#  5   Length                       9879 non-null   float64
#  6   Width                        9832 non-null   float64
#  7   Material                     8139 non-null   object
#  8   Location                     9852 non-null   object
#  9   Number of views last 7 days  9888 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 772.6+ KB

# %%
df.describe()
# Out:
#         Year Built       Length        Width  Number of views last 7 days
# count  9888.000000  9879.000000  9832.000000                  9888.000000
# mean   1893.192860    11.570017     3.520124                   149.160801
# std     460.201582     6.002820     1.220534                   151.819752
# min       0.000000     1.040000     0.010000                    13.000000
# 25%    1996.000000     7.470000     2.540000                    70.000000
# 50%    2007.000000    10.280000     3.330000                   108.000000
# 75%    2017.000000    13.930000     4.250000                   172.000000
# max    2021.000000   100.000000    25.160000                  3263.000000

# %%
df.head(10)
# Out:
#        Price  ... Number of views last 7 days
# 0   CHF 3337  ...                         226
# 1   EUR 3490  ...                          75
# 2   CHF 3770  ...                         124
# 3  DKK 25900  ...                          64
# 4   EUR 3399  ...                          58
# 5   CHF 3650  ...                         132
# 6   CHF 3600  ...                         474
# 7  DKK 24800  ...                         134
# 8   EUR 3333  ...                          45
# 9   EUR 3300  ...                         180
#
# [10 rows x 10 columns]

# %%
df.nunique()
# Out:
# Price                          3182
# Boat Type                       126
# Manufacturer                    910
# Type                             24
# Year Built                      122
# Length                         1612
# Width                           575
# Material                         11
# Location                       2995
# Number of views last 7 days     674
# dtype: int64

# %% [markdown]
# # Data Clean Up

# %% [markdown]
# To Dos:
# * 	\[Price\]:
# 	*  Parse Price into 'Currency' + 'Amount' columns 		✔
# 	*  Convert to Euros or USD  							✔
# * 	\[Boat Type\]:
# 	* 	Search & Group Similar Categories
# * 	\[Manufacturer\]:
# 	*	Remove "power boats"  									✔
# 	* 	Clean up characters 									✔
# 	* 	Fuzzy match manufacturers to reduce counts
# * 	\[Type\]:
# 	* 	Parse Column into 'Condition' + 'Fuel Type' columns		✔
# * 	\[Material\]:
# 	* 	- No Cleaning Needed -
# * 	\[Location\]:
# 	* 	Parse Country, Region & City
# 	* 	Correct Mispelled Words / Characters

# %% [markdown]
# ## Data Clean Up: All Columns

# %% [markdown]
# ## Data Clean Up:  'Price' Column

# %%
df[['Currency', 'Amount']] = df.Price.str.split(" ", expand=True )         # Split 'Price' into 'Currency' & 'Amount' 
print(df.Amount.isnull().values.any())                                     # Check there are non nulls in 'Amount'
print(df.Currency.isnull().values.any())                                   # Check there are non nulls in 'Currency'
print(df.Currency.unique())
# Out:
# False
# False
# ['CHF' 'EUR' 'DKK' 'Â£']

# %%
df['Currency'] = df['Currency'].str.replace('Â£', 'GBP')                   # Clean up British Pound currency chars
print(df.Currency.unique())
# Out:
# ['CHF' 'EUR' 'DKK' 'GBP']

# %%
df.Amount.str.isdigit().all()                       # Check that 'Amount' only contains numeric chars (no '.' or ',')
# Out:
# True

# %%
df['Amount'] = df['Amount'].astype('float64')         # Convert 'Amount' to numeric

# %%
# The following approach is too slow, as it has to perform 9k get requests

# curr = CurrencyRates()
# df['Amount (USD)'] = df.apply( lambda x: curr.convert( x.Currency, 'USD', x.Amount), axis = 1)

# %%
curr = CurrencyRates()
currencies = df.Currency.unique()
conversion_date = dt.datetime(2023, 1, 3)

rates = [curr.convert(i, 'USD', 1, conversion_date) for i in currencies]
rates_to_USD = dict(zip(currencies, rates))

print(rates_to_USD)
# Out:
# {'CHF': 1.0674157303370786, 'EUR': 1.0545, 'DKK': 0.1417910447761194, 'GBP': 1.1976421951662728}

# %%
df['Price (USD)'] = round(df['Amount'] * df['Currency'].map(rates_to_USD), 2)

# %% [markdown]
# ## Data Clean Up : 'Boat Type' Column

# %%
#t = df['Boat Type'].unique()
#sorted(t)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.groupby('Boat Type').size())
# Out:
# Boat Type
# Bowrider                                        301
# Bowrider,Cabin Boat,Deck Boat                     1
# Bowrider,Center console boat,Sport Boat           1
# Bowrider,Classic                                  1
# Bowrider,Deck Boat,Water ski                      1
# Bowrider,Motor Yacht,Sport Boat                   1
# Bowrider,Motor Yacht,Wakeboard/Wakesurf           1
# Bowrider,Sport Boat,Wakeboard/Wakesurf            2
# Bowrider,Wakeboard/Wakesurf                       1
# Cabin Boat                                      585
# Cabin Boat,Classic                                9
# Cabin Boat,Classic,Flybridge                      1
# Cabin Boat,Classic,Motor Yacht                    3
# Cabin Boat,Classic,Passenger boat                 1
# Cabin Boat,Classic,Trawler                        1
# Cabin Boat,Fishing Boat                           2
# Cabin Boat,Fishing Boat,House Boat                1
# Cabin Boat,Fishing Boat,Pilothouse                1
# Cabin Boat,Fishing Boat,Sport Boat                1
# Cabin Boat,Flybridge                              3
# Cabin Boat,Flybridge,Motor Yacht                  2
# Cabin Boat,Hardtop                                2
# Cabin Boat,Hardtop,Motor Yacht                    1
# Cabin Boat,Hardtop,Sport Boat                     1
# Cabin Boat,Hardtop,Trawler                        1
# Cabin Boat,House Boat                             3
# Cabin Boat,House Boat,Trawler                     1
# Cabin Boat,Motor Yacht                           10
# Cabin Boat,Motor Yacht,Offshore Boat              1
# Cabin Boat,Motor Yacht,Sport Boat                 7
# Cabin Boat,Motor Yacht,Trawler                    1
# Cabin Boat,Pilothouse                             1
# Cabin Boat,Pilothouse,Sport Boat                  1
# Cabin Boat,Sport Boat                             9
# Cabin Boat,Sport Boat,Wakeboard/Wakesurf          1
# Cabin Boat,Sport Boat,Water ski                   1
# Cabin Boat,Trawler                                3
# Catamaran                                        26
# Center console boat                             369
# Center console boat,Classic                       2
# Center console boat,Deck Boat,Sport Boat          1
# Center console boat,Deck Boat,Working Boat        1
# Center console boat,Fishing Boat,Sport Boat       1
# Center console boat,Sport Boat                    2
# Center console boat,Sport Boat,Water ski          1
# Classic                                          59
# Classic,Deck Boat                                 3
# Classic,Fishing Boat                              1
# Classic,Fishing Boat,Working Boat                 1
# Classic,Flybridge                                 8
# Classic,Hardtop,Motor Yacht                       1
# Classic,House Boat,Motor Yacht                    3
# Classic,House Boat,Passenger boat                 1
# Classic,Launch                                    4
# Classic,Mega Yacht                                1
# Classic,Motor Yacht                              26
# Classic,Motor Yacht,Passenger boat                1
# Classic,Motor Yacht,Sport Boat                    1
# Classic,Motor Yacht,Water ski                     1
# Classic,Motorsailer                               1
# Classic,Pontoon Boat                              4
# Classic,Pontoon Boat,Trawler                      1
# Classic,Runabout                                 59
# Classic,Runabout,Sport Boat                       3
# Classic,Runabout,Trawler                          1
# Classic,Sport Boat                               12
# Classic,Sport Boat,Trawler                        1
# Classic,Sport Boat,Water ski                      4
# Classic,Trawler                                   5
# Classic,Working Boat                              1
# Deck Boat                                       283
# Deck Boat,Pilothouse,Sport Boat                   1
# Deck Boat,Water ski                               1
# Fishing Boat                                    173
# Fishing Boat,Flybridge,Trawler                    1
# Fishing Boat,Hardtop,Pilothouse                   1
# Fishing Boat,Launch,Motor Yacht                   1
# Fishing Boat,Passenger boat,Sport Boat            1
# Fishing Boat,Pilothouse                           1
# Fishing Boat,Sport Boat                           1
# Flybridge                                      1194
# Flybridge,Hardtop,Motor Yacht                     1
# Flybridge,Motor Yacht                             7
# Flybridge,Pilothouse                              1
# Hardtop                                         507
# Hardtop,Mega Yacht,Motor Yacht                    1
# Hardtop,Motor Yacht                               3
# Hardtop,Motor Yacht,Sport Boat                    1
# Hardtop,Sport Boat                                1
# House Boat                                      145
# House Boat,Motor Yacht                            1
# House Boat,Motor Yacht,Trawler                    1
# House Boat,Sport Boat,Trawler                     1
# Ketch                                             1
# Launch                                           55
# Mega Yacht                                      108
# Motor Yacht                                    2720
# Motor Yacht,Sport Boat                            9
# Motor Yacht,Sport Boat,Trawler                    1
# Motor Yacht,Sport Boat,Water ski                  1
# Motor Yacht,Trawler                               4
# Motor Yacht,Wakeboard/Wakesurf                    1
# Motorsailer                                       3
# Offshore Boat                                    54
# Offshore Boat,Pilothouse                          1
# Offshore Boat,Sport Boat                          2
# Passenger boat                                   33
# Passenger boat,Runabout,Sport Boat                1
# Passenger boat,Working Boat                       2
# Pilothouse                                      613
# Pilothouse,Sport Boat                             1
# Pontoon Boat                                     91
# RIB                                               1
# Runabout                                         73
# Runabout,Sport Boat                               2
# Runabout,Sport Boat,Water ski                     3
# Sport Boat                                     1407
# Sport Boat,Wakeboard/Wakesurf                     4
# Sport Boat,Wakeboard/Wakesurf,Water ski           3
# Sport Boat,Water ski                              2
# Sport Boat,Working Boat                           1
# Trawler                                         679
# Wakeboard/Wakesurf                               58
# Wakeboard/Wakesurf,Water ski                      2
# Water ski                                        10
# Working Boat                                     44
# dtype: int64

# %%
df['Boat Type'].str.contains(',').sum()*100/df.shape[0]
# Out:
# 2.9935275080906147

# %%
df['Boat Type - Main'] = df['Boat Type'].map(lambda x: x.split(',')[0])
df['Boat Type - Subtype'] = df['Boat Type'].map(lambda x: x.split(',')[1] if len(x.split(',')) > 1 else '')
df['Boat Type - Subtype'].unique()
# Out:
# array(['', 'Working Boat', 'Classic', 'Pilothouse', 'Trawler',
#        'Sport Boat', 'Runabout', 'Motor Yacht', 'Launch', 'Pontoon Boat',
#        'Motorsailer', 'Wakeboard/Wakesurf', 'Water ski', 'Flybridge',
#        'Hardtop', 'House Boat', 'Mega Yacht', 'Deck Boat', 'Cabin Boat',
#        'Fishing Boat', 'Center console boat', 'Passenger boat'],
#       dtype=object)

# %%
print(df.groupby('Boat Type - Main').size())
# Out:
# Boat Type - Main
# Bowrider                310
# Cabin Boat              654
# Catamaran                26
# Center console boat     377
# Classic                 203
# Deck Boat               285
# Fishing Boat            179
# Flybridge              1203
# Hardtop                 513
# House Boat              148
# Ketch                     1
# Launch                   55
# Mega Yacht              108
# Motor Yacht            2736
# Motorsailer               3
# Offshore Boat            57
# Passenger boat           36
# Pilothouse              614
# Pontoon Boat             91
# RIB                       1
# Runabout                 78
# Sport Boat             1417
# Trawler                 679
# Wakeboard/Wakesurf       60
# Water ski                10
# Working Boat             44
# dtype: int64

# %%
print(df.groupby('Boat Type - Subtype').size())
# Out:
# Boat Type - Subtype
#                        9592
# Cabin Boat                1
# Center console boat       1
# Classic                  18
# Deck Boat                 6
# Fishing Boat              8
# Flybridge                14
# Hardtop                   8
# House Boat                8
# Launch                    5
# Mega Yacht                2
# Motor Yacht              63
# Motorsailer               1
# Passenger boat            1
# Pilothouse                6
# Pontoon Boat              5
# Runabout                 64
# Sport Boat               55
# Trawler                  12
# Wakeboard/Wakesurf        9
# Water ski                 5
# Working Boat              4
# dtype: int64

# %% [markdown]
# ## Data Clean Up: 'Manufacturer' Column

# %%
#t = df['Manufacturer'].fillna('None').unique()
#sorted(t)

# %%
df['Manufacturer'] = df['Manufacturer'].fillna('None')
df['Manufacturer'] = df['Manufacturer'].str.replace(' power boats', '')
df[df.Manufacturer.str.contains(r'[^0-9a-zA-Z -.]')].Manufacturer.unique()      # List misspelled Manufacturers
# Out:
# array(['BÃ©nÃ©teau', 'MÃ¤ndli', 'SkilsÃ¶', 'FÃ¼llemann', 'ManÃ²',
#        'KaasbÃ¸ll', 'TigÃ©', 'Ã\x96chsner', 'LÃ¼rssen Yachts', 'HervÃ©',
#        'Holland StahlverdrÃ¤nger', 'LÃ¼tje'], dtype=object)

# %%
df['Manufacturer'] = [fix_text(i) for i in df['Manufacturer']]
t = df['Manufacturer'].unique()
sorted(t)
# Out:
# ['2 emme marine',
#  '3B Craft',
#  'A. Mostes',
#  'AB Yachts',
#  'ACM Dufour',
#  'AGA-Marine',
#  'AICON Yachts',
#  'AL Custom',
#  'AM Yacht',
#  'AMS Marine Yachten',
#  'AMT',
#  'ARS Mare',
#  'AS Marine',
#  'ATOMIX',
#  'AW',
#  'AW Yachts',
#  'AXOPAR',
#  'AYROS',
#  'Abacus',
#  'Abati Yachts',
#  'Abeking & Rasmussen',
#  'Absolute',
#  'Acquaviva (IT)',
#  'Acroplast',
#  'Adagio Yachts',
#  'Adec',
#  'Adex Nautica',
#  'Adler',
#  'Admiral',
#  'Adventure',
#  'Aegean Yachts',
#  'Agder',
#  'Aicon',
#  'Airon Marine',
#  'Akerboom',
#  'Ala Blu',
#  'Alalunga',
#  'Albatro',
#  'Albemarle',
#  'Albin',
#  'Alen Yacht',
#  'Alfamarine',
#  'Alfastreet Marine',
#  'Allegra',
#  'Allround',
#  'Alpa',
#  'Altair',
#  'Altena',
#  'AluForce',
#  'AluVenture',
#  'Aluminiumjon',
#  'Amberg',
#  'Amel',
#  'Amer',
#  'Amerglass',
#  'American Marine',
#  'Ancora',
#  'Antaris',
#  'Anytec',
#  'Anytec Boats',
#  'Apreamare',
#  'Aquabat',
#  'Aquador',
#  'Aqualum',
#  'Aquanaut',
#  'Aquarius',
#  'Aquastar',
#  'Aquaviva',
#  'Arcoa',
#  'Argo',
#  'Arkos',
#  'Armee Suisse',
#  'Arp-Werft ',
#  'Arvor',
#  'Astinor',
#  'Astondoa',
#  'Astor',
#  'Atlanta',
#  'Atlantic Marine',
#  'Atlantic Motor Yachts',
#  'Atlantis',
#  'Austin Parker',
#  'Axis',
#  'Ayros',
#  'Azimut',
#  'Azzurro',
#  'B2 Marine',
#  'BLUEGAME',
#  'BLULINE (IT)',
#  'BM Nautica SRL',
#  'BMA',
#  'BSC',
#  'BWA',
#  'Babro',
#  'Back Cove',
#  'Baess',
#  'Baglietto',
#  'Baha',
#  'Baia',
#  'Baikal',
#  'Baja',
#  'Balt Yacht',
#  'Baltic',
#  'Bandido Yachts',
#  'Barkas',
#  'Barro',
#  'Bavaria',
#  'Bayliner',
#  'Bazzerla',
#  'Beachcraft',
#  'Beekmann',
#  'Bege',
#  'Bella',
#  'Bellcraft',
#  'Belliure',
#  'Benetti',
#  'Bering Yachts',
#  'Bertram',
#  'Bertram Yacht',
#  'Best',
#  'Biam',
#  'Bienchen ',
#  'Bimax',
#  'Biot',
#  'Birchwood',
#  'Blackfin',
#  'Blauwe Hand',
#  'Blohm + Voss',
#  'Blom',
#  'Blu Martin',
#  'Blue Navy',
#  'Blue Ocean',
#  'Blue Sailors',
#  'BlueCraft',
#  'Bluewater Yachts',
#  'Bluline',
#  'Blumar',
#  'Boatbuilding Academy Dorset',
#  'Boesch',
#  'Bombard',
#  'Bombardier',
#  'Bond Yachts',
#  'Bootbau Frei',
#  'Boston Whaler',
#  'Brabus',
#  'Brandsma',
#  'Brig',
#  'Brizo Yachts',
#  'Broom',
#  'Brunnert-Grimm',
#  'Bruno Abbate',
#  'Bryant Boats',
#  'Bucher',
#  'Buetzfleth',
#  'Bugari',
#  'Burger',
#  'Buster',
#  'Bénéteau',
#  'C.N. Tigullio',
#  'CAD Marine',
#  'Cabo',
#  'Calafuria',
#  'Calcagno',
#  'Campion',
#  'Camuffo',
#  'Canados',
#  'Cantiere delle Marche',
#  'Cantieri Estensi',
#  'Cantieri Nautici Dalla Pieta',
#  'Cantieri Nautici Ferrario',
#  'Cantieri Nautici Solcio',
#  'Cantieri Navali Arno',
#  'Cantieri Navali di Livorno',
#  'Cantieri Schiavone',
#  'Cantieri di Pisa',
#  'Cantieri di Sarnico',
#  'Cap Ferret',
#  'Capelli',
#  'Caravelle',
#  'Carnevali',
#  'Carolina Classic',
#  'Carver',
#  'Cascaruda',
#  'Catarsi',
#  'Catfish',
#  'Cayman',
#  'Celebrity',
#  'Center Craft',
#  'Centurion',
#  'Century',
#  'Chaparral',
#  'Checkmate',
#  'Chris Craft',
#  'Chrysler',
#  'Chung Hwa',
#  'Cigala & Bertinetti',
#  'Cigarette',
#  'Cipax AS',
#  'Clear',
#  'Coaster',
#  'Cobalt',
#  'Cobra Yachts',
#  'Cobrey',
#  'Colombo',
#  'Colvic',
#  'Comar',
#  'Comitti',
#  'Compromis',
#  'Conam',
#  'Concordia',
#  'Condor Yachting',
#  'Cormate',
#  'Coronet',
#  'Correct Craft',
#  'Corsiva',
#  'Corvette Cruisers',
#  'Costruzioni Navali Srl',
#  'Couach',
#  'Coverline',
#  'Cox Marine',
#  'Cramar',
#  'Cranchi',
#  'Crescent',
#  'Crestliner',
#  'Crownline',
#  'Cruisers Yachts',
#  'Curvelle',
#  'Cytra',
#  'D-Boat',
#  'Dacapo',
#  'Dalla Pieta',
#  'Damor',
#  'DarekCo',
#  'Dawncraft',
#  'De Antonio Yachts',
#  'De Boarnstream',
#  'De Groot',
#  'De Vries',
#  'De Wiel',
#  'Dellapasqua',
#  'Delphia',
#  'Delta Powerboats',
#  'Di Donna',
#  'Diano',
#  'Doerak Sneek',
#  'Doggersbank',
#  'Dominator',
#  'Donzi',
#  'Doqueve',
#  'Doral',
#  'Draco',
#  'Drago Boats',
#  'Drettmann',
#  'Dufour',
#  'Dynasty',
#  'ERC',
#  'EVO',
#  'Ebbtide',
#  'Ecofiber',
#  'Ecoline',
#  'Edership',
#  'EdgeWater',
#  'Egemar',
#  'Egon Bredgaard',
#  'Elan',
#  'Elegance',
#  'Elling',
#  'Enterprise Marine',
#  'Envision',
#  'Eolo',
#  'Erman Yachting',
#  'Ernst Riss ',
#  'Escape Sloepen',
#  'Eurobanker',
#  'Eurocrown',
#  'Europe Marine',
#  'Euroship',
#  'Explorer',
#  'FFW Sealver',
#  'Faeton',
#  'Fairline',
#  'Falcon Yachts',
#  'Fartes',
#  'Faul',
#  'Feltz',
#  'Ferretti',
#  'Fiart Mare',
#  'Fiberline',
#  'Fibramar',
#  'Fidego',
#  'Filippetti',
#  'Fincantieri Yachts',
#  'Finnlineboats',
#  'Finnmaster',
#  'Fipa Italiana',
#  'Fjord',
#  'Fjord Plast',
#  'Fletcher',
#  'Flevo',
#  'Flipper',
#  'Flying Shark',
#  'Forbina',
#  'Formula',
#  'Formula Cruisers',
#  'Fountain',
#  'Fountaine Pajot',
#  'Four Winns',
#  'Franchini',
#  'Fratelli Aprea',
#  'Frauscher',
#  'Freedom',
#  'Funcraft',
#  'Futuro',
#  'Füllemann',
#  'GS Nautica',
#  'Gagliotta',
#  'Galaxy',
#  'Galeon',
#  'Galia',
#  'Gallart',
#  'Ganz Boats',
#  'Garin',
#  'Gavazzi Luciano',
#  'Gianetti',
#  'Gibert Marine',
#  'Gillissen',
#  'GioMare',
#  'Giorgi',
#  'Giudecca',
#  'Glacer',
#  'Glastron',
#  'Gobbi',
#  'Gouwerok',
#  'Grady White Boats',
#  'Grand Banks',
#  'Grandezza',
#  'Graso',
#  'Greenline',
#  'Grginic',
#  'Gropp',
#  'Gruno',
#  'Gulf Craft',
#  'Guy Couach',
#  'HI-Star',
#  'HT Houseboats',
#  'Haber',
#  'Hagenah',
#  'Haines',
#  'Haines Marine',
#  'Hans A. Deerberg',
#  'Hanto',
#  'Hardy Marine',
#  'Harris FloteBote',
#  'Hasler',
#  'Hatecke',
#  'Hatteras',
#  'Heesen Yachts',
#  'Heinrich',
#  'Hellingskip',
#  'Hellwig',
#  'Helstede',
#  'Hemiksem',
#  'Hensa ',
#  'Hervé',
#  'Heyday',
#  'Hille',
#  'Hilter',
#  'Hiltergerke',
#  'Hitzler-Werft Regensburg',
#  'HoWa',
#  'Hock',
#  'Hoekstra',
#  'Holland Boat',
#  'Holland Stahlverdränger',
#  'Hollandia',
#  'Hooveld',
#  'Horizon Yacht',
#  'Hoya',
#  'Huber',
#  'Hunter',
#  'Hunton',
#  'Hustler',
#  'IMP Boats',
#  'IRON',
#  'ISA Yachts',
#  'Ibis',
#  'Ibiza Boats',
#  'Idea Marine',
#  'Ijlstervlet',
#  'Ilver',
#  'Innovazione&Progetti',
#  'Innovazioni e Progetti',
#  'Integrity',
#  'Inter',
#  'Interboat DE',
#  'Intermare',
#  'Interster',
#  'Intrepid',
#  'Invader',
#  'Invictus',
#  'Island Gypsy',
#  'Italcraft',
#  'Italmar',
#  'Italmarine',
#  'Italversil',
#  'Itama',
#  'J2J Service',
#  'Jacabo',
#  'Jaguar',
#  'Jan Van Gent',
#  'Janmor',
#  'Jans',
#  'Javazzo',
#  'Jeanneau',
#  'Jetten',
#  'Joda',
#  'Johnson',
#  'Johnson Yachts',
#  'Jongert',
#  'Jouandoudet',
#  'KOK',
#  'Kaasbøll',
#  'Kaiser Bootsmanufaktur',
#  'Kammin',
#  'Kapiteinssloep',
#  'Karel',
#  'Karnic',
#  'Katwijker',
#  'Kelt',
#  'Kempala (NL)',
#  'Kempers',
#  'Kiel Classic',
#  'Kimple',
#  'Kirie',
#  'Klase A',
#  'Knierim Yachtbau',
#  'Koopmans',
#  'Kramer',
#  'Kraps',
#  'Kronborg Marine',
#  'La Mare',
#  'Lagoon',
#  'Lambro',
#  'Lamor',
#  'Larson',
#  'Lavagna',
#  'Leidi',
#  'Lema',
#  'Lengers',
#  'Leopard',
#  'Lex Boats',
#  'Liberty',
#  'Linden',
#  'Linder',
#  'Linex',
#  'Linssen',
#  'Loon',
#  'Luhrs',
#  'Lund Boats',
#  'Lunde',
#  'Lürssen Yachts',
#  'Lütje',
#  'MAS',
#  'MBK',
#  'MCY',
#  'MMS',
#  'MP Watersport',
#  'Magic Yachts',
#  'Magnum',
#  'Mainship',
#  'Maiora',
#  'Majesty Yachts',
#  'Majoni',
#  'Makma',
#  'Mako Boats',
#  'Malibu',
#  'Mangusta',
#  'Manò',
#  'Marco Yachts',
#  'Marex',
#  'Marhen',
#  'Mariah',
#  'Marian',
#  'Marieholm',
#  'Maril',
#  'Marina Brodersby',
#  'Marine',
#  'Marine Offshore',
#  'Marine Pro',
#  'Marine Projects',
#  'Marine Yachting',
#  'Marinello',
#  'Marino',
#  'Marino CN',
#  'Marino Costruzioni Nautiche',
#  'Marquis',
#  'Martin',
#  'Master',
#  'MasterCraft',
#  'Maxi Dolphin',
#  'Maxima',
#  'Maxum',
#  'Mazury',
#  'Meier',
#  'Menorquin',
#  'Meridian Yachts',
#  'Mery Nautic',
#  'Milan ',
#  'Mingolla',
#  'Minor',
#  'Mira',
#  'Mirage',
#  'Mirakul',
#  'Mochi Craft',
#  'Momenta',
#  'Monachus',
#  'Mondo marine',
#  'Monte Carlo',
#  'Monte Fino',
#  'Monterey',
#  'Moomba',
#  'Moonday',
#  'Moonen',
#  'Moonfleet',
#  'Moonraker',
#  'Morningstar',
#  'Moschini',
#  'Motiva',
#  'Motocraft',
#  'Motomar',
#  'Myabca',
#  'Mändli',
#  'NUVA Yachts',
#  'Nadirmarine',
#  'Nasbo',
#  'Nautica',
#  'Nautica Esposito',
#  'Nautilus',
#  'Nautique',
#  'Navalia',
#  'Navalplastica',
#  'Need Yacht',
#  'Neptunus',
#  'Neptunus Yachts',
#  'Nicols',
#  'Nidelv',
#  'Nimbus',
#  'Nireus',
#  'None',
#  'Nor Star',
#  'Nor-Dan',
#  'Nord Star',
#  'Nord West',
#  'Nordic',
#  'Nordkapp',
#  'Nordmanns',
#  'Nordmaster',
#  'Nordson',
#  'NorthMaster',
#  'Northern Marine',
#  'Northshore Yachts',
#  'Novurania',
#  'Numarine',
#  'Numo',
#  'Nuova Jolly',
#  'Nussbaumer',
#  'Ocea',
#  'Ocean Alexander',
#  'Ocean Bay',
#  'Ocean Master (US)',
#  'Ocean Yachts',
#  'Ockelbo',
#  'Ocqueteau',
#  'Off-Course',
#  'Olympic',
#  'Oost',
#  'Orca',
#  'Orkney',
#  'Orskov Skibsvaerft',
#  'Osprey',
#  'Ott Werft',
#  'Overblue',
#  'Overmarine',
#  'Oyster',
#  'PR Marine',
#  'Pacific',
#  'Pacific Craft',
#  'Palmer Johnson',
#  'Pantera',
#  'Paragon',
#  'Parente',
#  'Parker',
#  'Pavati',
#  'Pearl',
#  'Pearlsea Yachts',
#  'Pedrazzini',
#  'Pedro',
#  'Pegazus',
#  'Pegiva',
#  'Performance',
#  'Perini Navi Spa',
#  'Permare',
#  'Pershing',
#  'Pfeil',
#  'Piantoni',
#  'Piantoni (IT)',
#  'Piculjan Marine',
#  'Pikmeerkruiser',
#  'Pioner',
#  'Pirelli',
#  'Platinum',
#  'Poca',
#  'Polar',
#  'Polar Boats',
#  'Polaris',
#  'Poldijk Jachtbouw B.V.',
#  'Pollard',
#  'Pollini',
#  'Portofino Marine',
#  'Posillipo',
#  'Premier',
#  'Premiere Yacht',
#  'President',
#  'Prestige Yachts',
#  'Primatist',
#  'Primeur',
#  'Princess',
#  'Prins van Oranje',
#  'Prinz',
#  'Privateer',
#  'Pro-Line',
#  'Proficiat',
#  'Pursuit',
#  'Q-Yachts',
#  'QErre',
#  'Queens Yachts',
#  'Quicksilver',
#  'Quicksilver (Brunswick Marine)',
#  'Quicksilver Inflatables',
#  'Raffaelli',
#  'Rampage',
#  'Rancraft',
#  'Rand Boats',
#  'Ranger',
#  'Ranieri',
#  'Ranieri International',
#  'Rapsody',
#  'Rayglass',
#  'ReLine',
#  'Recla',
#  'Regal',
#  'Reinell',
#  'Remus',
#  'Renken',
#  'Rhea',
#  'Richard Dunston',
#  'Rigiflex',
#  'Rijnkruiser',
#  'Rijo Kruiser',
#  'Rinker',
#  'Rio',
#  'Rio Iberica',
#  'Riva',
#  'Riva Bertram',
#  'Rivers and Tides',
#  'Riviera',
#  'Rizzardi',
#  'Robalo',
#  'Rodman',
#  'Rodriguez Group (Italyachts)',
#  'Rohn',
#  'Romar',
#  'Rose Island',
#  'Royal Denship',
#  'SACS',
#  'SAS-Vektor',
#  'SAY',
#  'SBM',
#  'ST',
#  'Sabre',
#  'Safter Marine',
#  'Saga',
#  'Sagemar',
#  'Salmeri Boote',
#  'Salpa',
#  'San Remo',
#  'Sanlorenzo',
#  'Saphire',
#  'Sarins',
#  'Sarnico',
#  'Sasga Yachts',
#  'Saura',
#  'Saver',
#  'Saxdor',
#  'Scand',
#  'Scandinavia',
#  'Scanner',
#  'Scar',
#  'Scarab',
#  'Scarani',
#  'Schachner',
#  'Schaefer',
#  'Schlosswerft',
#  'Schneiter',
#  'Schottel',
#  'Schwarz',
#  'Schweizer',
#  'Schweizer Bateaux',
#  'Sciallino',
#  'Scout Boats',
#  'Sea Pro',
#  'Sea Ray',
#  'Sea Sprite',
#  'Sea-Doo',
#  'Seaco',
#  'Seacode',
#  'Seagull',
#  'Sealine',
#  'Sealver',
#  'Searider',
#  'Seaswirl',
#  'Seaway',
#  'Seebold',
#  'Selco',
#  'Selection Boats',
#  'Selene',
#  'Selje',
#  'Selva',
#  'Sensation',
#  'Ses Yachts',
#  'Sessa',
#  'Shiren',
#  'Siemer',
#  'Sigrist',
#  'Silver',
#  'Silverline',
#  'Skagen',
#  'Skagerrak',
#  'Skarpnes',
#  'Skibsplast',
#  'Skilso',
#  'Skilsö',
#  'Slepsk',
#  'Smartboat',
#  'Smartliner',
#  'Smelne',
#  'Solare',
#  'Solcio',
#  'Sonic',
#  'Sossego',
#  'Spertini',
#  'Sport Craft',
#  'Staempfli',
#  'Stalder',
#  'Stama',
#  'Starcraft',
#  'Starfisher',
#  'Starweld',
#  'Statement Marine',
#  'Steilsteven',
#  'Steiner',
#  'Stickl',
#  'Stilecatalini',
#  'Sting',
#  'Stingray',
#  'Storebro',
#  'Stormer',
#  'Striker',
#  'Succes',
#  'Sunbird',
#  'Suncamper',
#  'Sunchaser',
#  'Suncoast',
#  'Sunreef',
#  'Sunseeker',
#  'Super Kaagkruiser',
#  'Super Lauwersmeer',
#  'Super van Craft',
#  'Supra',
#  'Suzuki',
#  'Swiss Craft',
#  'Swordsman',
#  'Sylvan Marine',
#  'Symbol Yachts',
#  'Ta Yang',
#  'Tahoe',
#  'Targa',
#  'Tarquin',
#  'Tauscheck',
#  'Techno Yachts',
#  'Technohull',
#  'Technus',
#  'Tecnomar',
#  'Tecnomarine',
#  'Tecnorib',
#  'Tegernseer Bootsbau',
#  'Teltow Werft',
#  'Ten Broeke',
#  'Terhi',
#  'Terra Nauta',
#  'The Captains',
#  'Thermo Yacht',
#  'Thoma',
#  'Thompson',
#  'Thunderbird',
#  'Tiara',
#  'Tigé',
#  'Tinn-Silver',
#  'Titanium',
#  'Tjeukemer',
#  'Tony Giugliano',
#  'Topaz',
#  'Tornado',
#  'Tracker Marine',
#  'Trader Motor Yachts',
#  'Trawler',
#  'Treffer',
#  'Tresfjord',
#  'Trimarchi ',
#  'Tristan',
#  'Triton',
#  'Trojan',
#  'Trophy',
#  'Tryvia',
#  'Tuccoli',
#  'Tullio Abbate',
#  'UMS-Boat',
#  'Ultramar',
#  'Unica Yacht',
#  'Uniesse',
#  'Uttern',
#  'V2 Boats ',
#  'VBoats',
#  'VEB',
#  'VICEM',
#  'VTS Boats',
#  'VZ Cantiere Nautico',
#  'Vacance',
#  'Valiant',
#  'Valk',
#  'Valkkruiser',
#  'VanDutch',
#  'Vedette',
#  'Veha',
#  'Ventus',
#  'Verhoeven',
#  'Vertens',
#  'Verus',
#  'Victoria',
#  'Viking',
#  'Viking (GB)',
#  'Viking Marin',
#  'Viknes',
#  'Viko',
#  'Viko Yachts',
#  'Viksund',
#  'Viper',
#  'Vismara',
#  'Vitech',
#  'Vizianello',
#  'Vizion',
#  'Volvo',
#  'Voyager',
#  'Vri-Jon',
#  'Vrijbuiter',
#  'Waddenkruiser',
#  'Wajer',
#  'Wake',
#  'Walser',
#  'Waltjen',
#  'Waterdream',
#  'Waterland',
#  'Webbcraft',
#  'WeiBo',
#  'Weidling',
#  'Wellcraft',
#  'Werner ',
#  'West Bay',
#  'Westwind',
#  'Whaly',
#  'White Shark',
#  'Wicabo',
#  'Wider',
#  'Wiking',
#  'Williams',
#  'Wim van der Valk',
#  'Windy',
#  'Windy Oceancraft',
#  'Winga',
#  'Witti',
#  'XL Marine',
#  'XO Boats',
#  'Yacht Service SP. z o.o. ',
#  'Yachting France',
#  'Yachtwerft Berlin',
#  'Yamaha',
#  'Yamarin',
#  'Yaretti',
#  'Z-Yacht',
#  'ZAR Formenti',
#  'Zeeland Jachtbouw',
#  'Zeta Group',
#  'Zetacraft',
#  'Zijlmans',
#  'Zodiac',
#  'Zuiderzee',
#  'de Ruiter',
#  'van Wijk',
#  'van de Werf',
#  'van der Heijden',
#  'Öchsner']

# %%
mfct_count = pd.DataFrame({ 'count' : df.groupby('Manufacturer').size()}).reset_index() 
mfct_singles = mfct_count[mfct_count['count'] == 1] 
mfct_singles.sum()
# Out:
# Manufacturer    2 emme marineAB YachtsAGA-MarineAL CustomAMS M...
# count                                                         397
# dtype: object

# %%
df.loc[df['Manufacturer'].isin(mfct_singles['Manufacturer']), 'Manufacturer'] = 'Other'  # Group Boat Mfct with 1 boat to 'Other' Category

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.groupby('Manufacturer').size().sort_values(ascending = False))
# Out:
# Manufacturer
# None                              1338
# Bénéteau                           631
# Jeanneau                           537
# Other                              397
# Sunseeker                          383
# Princess                           241
# Sea Ray                            239
# Cranchi                            219
# Azimut                             215
# Bavaria                            185
# Fairline                           172
# Quicksilver (Brunswick Marine)     167
# Sessa                              148
# Bayliner                           142
# Sealine                            120
# Quicksilver                        118
# Prestige Yachts                    108
# Galeon                              94
# Regal                               90
# Riva                                77
# Linssen                             70
# Windy                               64
# Ferretti                            63
# Parker                              62
# Boesch                              55
# Pershing                            54
# Four Winns                          50
# Gobbi                               46
# Nimbus                              45
# Yamarin                             42
# Sanlorenzo                          41
# Chaparral                           40
# Rodman                              40
# Boston Whaler                       39
# Invictus                            39
# Saver                               39
# Atlantis                            39
# Astondoa                            39
# Viper                               37
# Crownline                           37
# Pedro                               35
# Chris Craft                         35
# Fjord                               34
# Marinello                           34
# Absolute                            34
# Menorquin                           33
# Rhea                                33
# Fiart Mare                          33
# Marex                               32
# Campion                             31
# Apreamare                           30
# Airon Marine                        29
# Ranieri International               28
# Glastron                            28
# Greenline                           27
# Drago Boats                         26
# Raffaelli                           26
# MasterCraft                         25
# Maxum                               25
# Frauscher                           25
# Rinker                              24
# Draco                               24
# Aquador                             24
# Cobalt                              24
# Ocqueteau                           24
# Innovazioni e Progetti              24
# Formula                             23
# Dellapasqua                         22
# Mochi Craft                         22
# Monterey                            22
# Faeton                              22
# Cayman                              21
# Rio                                 21
# Buster                              20
# Cruisers Yachts                     19
# Linder                              19
# AMT                                 19
# Bella                               19
# Neptunus                            19
# Majesty Yachts                      18
# Grand Banks                         18
# Nautique                            17
# Smelne                              17
# Larson                              17
# Performance                         17
# Manò                                17
# Karnic                              16
# Storebro                            16
# Colombo                             16
# Eolo                                16
# Ilver                               16
# Terhi                               16
# Galia                               16
# Dominator                           16
# Pioner                              15
# Rizzardi                            15
# Carnevali                           15
# Aicon                               15
# Crescent                            15
# Tullio Abbate                       15
# Finnmaster                          15
# Uniesse                             14
# Ganz Boats                          14
# Scand                               14
# Nordkapp                            14
# B2 Marine                           14
# Baia                                14
# Riviera                             14
# Succes                              14
# Elan                                13
# Wellcraft                           13
# Flipper                             13
# Hatteras                            13
# Tiara                               13
# AXOPAR                              13
# Doral                               13
# Intermare                           13
# Conam                               12
# Cantieri Estensi                    12
# Gruno                               12
# Bruno Abbate                        12
# Capelli                             12
# Valkkruiser                         12
# Viking                              12
# Piantoni (IT)                       12
# Salpa                               11
# Kelt                                11
# Fountaine Pajot                     11
# Aquanaut                            11
# De Boarnstream                      11
# Bertram Yacht                       11
# Nidelv                              11
# VBoats                              11
# Carver                              11
# Integrity                           11
# Maiora                              11
# ACM Dufour                          10
# Allegra                             10
# Altena                              10
# Valk                                10
# XO Boats                            10
# Super van Craft                     10
# Pursuit                             10
# Broom                               10
# Correct Craft                       10
# Sting                               10
# Canados                             10
# Malibu                              10
# Proficiat                            9
# Posillipo                            9
# Pedrazzini                           9
# Selection Boats                      9
# Rapsody                              9
# Master                               9
# MCY                                  9
# Italmar                              9
# Itama                                9
# van der Heijden                      9
# VanDutch                             9
# Edership                             9
# Benetti                              9
# AluForce                             9
# Vri-Jon                              9
# Smartliner                           8
# Bandido Yachts                       8
# Selene                               8
# Grandezza                            8
# Olympic                              8
# Marine                               8
# Starfisher                           8
# Italcraft                            8
# Stingray                             8
# Tornado                              8
# Doqueve                              8
# Leopard                              8
# Hollandia                            8
# Clear                                8
# Tecnomar                             8
# Ranieri                              8
# Elegance                             8
# DarekCo                              8
# Birchwood                            7
# Dalla Pieta                          7
# Bertram                              7
# Comitti                              7
# BlueCraft                            7
# Scarab                               7
# IRON                                 7
# Sunchaser                            7
# Corsiva                              7
# Mangusta                             7
# Mändli                               7
# Moonday                              7
# Delphia                              7
# Saxdor                               7
# Elling                               7
# President                            7
# Pirelli                              7
# Baglietto                            7
# Tecnorib                             7
# Orkney                               7
# Balt Yacht                           7
# Primatist                            6
# Mingolla                             6
# Zijlmans                             6
# Inter                                6
# Sciallino                            6
# Alfastreet Marine                    6
# Pro-Line                             6
# A. Mostes                            6
# Baikal                               6
# Arcoa                                6
# Sensation                            6
# Cantieri di Sarnico                  6
# Silver                               6
# Marine Projects                      6
# Cantieri Nautici Ferrario            6
# Arvor                                6
# Polaris                              6
# Guy Couach                           6
# De Antonio Yachts                    6
# Thoma                                6
# Brandsma                             5
# Giorgi                               5
# Vizion                               5
# Lema                                 5
# Albemarle                            5
# Cantieri di Pisa                     5
# Brizo Yachts                         5
# Overmarine                           5
# Brabus                               5
# Portofino Marine                     5
# Solcio                               5
# Seaswirl                             5
# Pikmeerkruiser                       5
# Yaretti                              5
# Moomba                               5
# Gianetti                             5
# Atlantic Marine                      5
# Atlantic Motor Yachts                5
# Wim van der Valk                     5
# Tuccoli                              5
# Nord Star                            5
# Baja                                 5
# De Groot                             5
# Selva                                5
# Ocean Master (US)                    5
# Sunreef                              5
# Pacific                              5
# Sarnico                              5
# AS Marine                            5
# Ijlstervlet                          5
# Hilter                               5
# Cigarette                            5
# AICON Yachts                         5
# Saga                                 5
# Century                              5
# Füllemann                            4
# Pfeil                                4
# Biam                                 4
# Sagemar                              4
# Cytra                                4
# Cobrey                               4
# Di Donna                             4
# Hellwig                              4
# Gillissen                            4
# Monte Carlo                          4
# Heyday                               4
# Belliure                             4
# Skibsplast                           4
# Motomar                              4
# NUVA Yachts                          4
# Cormate                              4
# Hock                                 4
# Delta Powerboats                     4
# BLUEGAME                             4
# Marquis                              4
# Damor                                4
# Pacific Craft                        4
# Seaway                               4
# Nordmaster                           4
# BMA                                  4
# Huber                                4
# Coronet                              4
# Ultramar                             4
# Gagliotta                            4
# Kaiser Bootsmanufaktur               4
# Maxima                               4
# ST                                   4
# Stickl                               4
# Filippetti                           4
# Rand Boats                           4
# Trimarchi                            4
# ReLine                               4
# Treffer                              4
# Majoni                               4
# SAY                                  4
# Swiss Craft                          4
# Antaris                              4
# Safter Marine                        4
# Fiberline                            4
# SAS-Vektor                           4
# Coverline                            4
# Centurion                            4
# Aquastar                             4
# Abacus                               4
# EdgeWater                            4
# Hardy Marine                         4
# Sunbird                              4
# Scarani                              3
# Albatro                              3
# Remus                                3
# Ala Blu                              3
# Rio Iberica                          3
# Alalunga                             3
# Sarins                               3
# Alfamarine                           3
# Uttern                               3
# Alpa                                 3
# Pegazus                              3
# Fipa Italiana                        3
# Fletcher                             3
# Doggersbank                          3
# Robalo                               3
# Polar Boats                          3
# Polar                                3
# Prinz                                3
# Sea-Doo                              3
# Diano                                3
# Permare                              3
# XL Marine                            3
# Veha                                 3
# Piculjan Marine                      3
# Astor                                3
# Altair                               3
# de Ruiter                            3
# Arkos                                3
# Nautica Esposito                     3
# Starcraft                            3
# Babro                                3
# Makma                                3
# Grady White Boats                    3
# Cramar                               3
# Jacabo                               3
# Stama                                3
# Vacance                              3
# Chung Hwa                            3
# Gropp                                3
# Jetten                               3
# Whaly                                3
# Bryant Boats                         3
# Funcraft                             3
# Supra                                3
# Cabo                                 3
# Katwijker                            3
# Vismara                              3
# Linex                                3
# Lagoon                               3
# Cobra Yachts                         3
# Tahoe                                3
# Hille                                3
# Barkas                               3
# Beachcraft                           3
# Hiltergerke                          3
# Skagerrak                            3
# Holland Stahlverdränger              3
# Morningstar                          3
# Bege                                 3
# Innovazione&Progetti                 3
# Mirakul                              3
# Mira                                 3
# Condor Yachting                      3
# Symbol Yachts                        2
# Tecnomarine                          2
# Tigé                                 2
# Schweizer                            2
# Super Lauwersmeer                    2
# ZAR Formenti                         2
# Schweizer Bateaux                    2
# Terra Nauta                          2
# VICEM                                2
# Vizianello                           2
# Viko                                 2
# WeiBo                                2
# Tony Giugliano                       2
# Trawler                              2
# Shiren                               2
# Siemer                               2
# Skagen                               2
# Wicabo                               2
# Tryvia                               2
# Skilso                               2
# Trojan                               2
# Spertini                             2
# White Shark                          2
# Triton                               2
# Sport Craft                          2
# Windy Oceancraft                     2
# Viking Marin                         2
# Staempfli                            2
# Tristan                              2
# Viking (GB)                          2
# Stilecatalini                        2
# Viknes                               2
# Waterland                            2
# Striker                              2
# Yamaha                               2
# Thermo Yacht                         2
# 3B Craft                             2
# Scanner                              2
# Ebbtide                              2
# Egemar                               2
# Enterprise Marine                    2
# Eurobanker                           2
# Europe Marine                        2
# Euroship                             2
# FFW Sealver                          2
# Falcon Yachts                        2
# Flying Shark                         2
# Fratelli Aprea                       2
# Futuro                               2
# Gallart                              2
# Garin                                2
# Gibert Marine                        2
# Giudecca                             2
# Gouwerok                             2
# Grginic                              2
# Gulf Craft                           2
# HT Houseboats                        2
# Haber                                2
# Haines                               2
# Haines Marine                        2
# Heesen Yachts                        2
# Heinrich                             2
# Ecoline                              2
# Dufour                               2
# Sasga Yachts                         2
# Costruzioni Navali Srl               2
# AM Yacht                             2
# ARS Mare                             2
# AW                                   2
# Adagio Yachts                        2
# Admiral                              2
# Albin                                2
# Amberg                               2
# Amer                                 2
# Argo                                 2
# Atlanta                              2
# Axis                                 2
# Beekmann                             2
# Bimax                                2
# Blackfin                             2
# Blu Martin                           2
# Bugari                               2
# Camuffo                              2
# Cantieri Navali di Livorno           2
# Cascaruda                            2
# Catarsi                              2
# Center Craft                         2
# Comar                                2
# Corvette Cruisers                    2
# Hellingskip                          2
# Holland Boat                         2
# Hooveld                              2
# Horizon Yacht                        2
# Mery Nautic                          2
# Minor                                2
# Monachus                             2
# Monte Fino                           2
# Moonen                               2
# Neptunus Yachts                      2
# Nicols                               2
# Nireus                               2
# Nordic                               2
# Nordson                              2
# NorthMaster                          2
# Numarine                             2
# Ocean Alexander                      2
# Ocean Bay                            2
# Overblue                             2
# Pearl                                2
# Platinum                             2
# Premiere Yacht                       2
# Privateer                            2
# Renken                               2
# SACS                                 2
# Salmeri Boote                        2
# San Remo                             2
# Mazury                               2
# Marino                               2
# Marine Offshore                      2
# Koopmans                             2
# Hustler                              2
# Ibiza Boats                          2
# Idea Marine                          2
# Intrepid                             2
# Invader                              2
# Italmarine                           2
# Joda                                 2
# Johnson                              2
# Karel                                2
# Kimple                               2
# Kramer                               2
# Marina Brodersby                     2
# Lambro                               2
# Loon                                 2
# Lund Boats                           2
# MBK                                  2
# MP Watersport                        2
# Magnum                               2
# Mainship                             2
# Marhen                               2
# Mariah                               2
# Maril                                2
# La Mare                              2
# dtype: int64

# %% [markdown]
# ## Data Clean Up: 'Type' Column

# %%
t = df['Type'].fillna('None').unique()
#sorted(t)
print(df.groupby('Type').size().sort_values(ascending = False))
# Out:
# Type
# Used boat,Diesel                4140
# Used boat,Unleaded              1686
# Used boat                       1462
# new boat from stock,Unleaded    1107
# new boat from stock              665
# new boat from stock,Diesel       291
# new boat on order,Unleaded       150
# Display Model,Unleaded            75
# new boat on order,Diesel          61
# new boat on order                 61
# Diesel                            57
# Used boat,Electric                27
# Unleaded                          22
# Display Model,Diesel              19
# Display Model                     18
# new boat from stock,Electric      18
# Used boat,Gas                     10
# Display Model,Electric             6
# new boat from stock,Gas            2
# Used boat,Propane                  1
# Electric                           1
# new boat from stock,Hybrid         1
# Display Model,Gas                  1
# Used boat,Hybrid                   1
# dtype: int64

# %%
[*set(np.char.partition(df['Type'].fillna('None').unique().tolist(), ',').flatten().tolist())]
# Out:
# ['',
#  'None',
#  'Electric',
#  'Display Model',
#  'Unleaded',
#  'new boat on order',
#  'Hybrid',
#  'new boat from stock',
#  'Propane',
#  'Diesel',
#  ',',
#  'Used boat',
#  'Gas']

# %%
condition_lst = ['Used boat', 'new boat from stock', 'new boat on order', 'Used boat', 'Display Model' ]
fuel_lst = ['Diesel', 'Electric', 'Gas', 'Hybrid', 'Unleaded', 'Propane' ]

# %%
df['Condition'] = df['Type'].str.extract("(" + "|".join(condition_lst) +")", expand=False)
df['Fuel'] = df['Type'].str.extract("(" + "|".join(fuel_lst) +")", expand=False)

# %%
df.tail(100)
# Out:
#          Price            Boat Type  ...            Condition      Fuel
# 9788  EUR 8000           House Boat  ...            Used boat       NaN
# 9789  EUR 8000           Sport Boat  ...            Used boat  Unleaded
# 9790  EUR 8000           Pilothouse  ...            Used boat  Unleaded
# 9791  EUR 8000           Cabin Boat  ...            Used boat  Unleaded
# 9792  EUR 8000  Center console boat  ...            Used boat  Unleaded
# ...        ...                  ...  ...                  ...       ...
# 9883  CHF 4900           Sport Boat  ...            Used boat  Unleaded
# 9884  EUR 4516           Sport Boat  ...  new boat from stock       NaN
# 9885  EUR 4499           Sport Boat  ...  new boat from stock  Unleaded
# 9886  EUR 4300         Pontoon Boat  ...  new boat from stock       NaN
# 9887  CHF 3780         Fishing Boat  ...  new boat from stock       NaN
#
# [100 rows x 17 columns]

# %%
df['Fuel'] = df['Fuel'].str.replace('Propane', 'Gas')

# %%
print(df.groupby('Condition').size().sort_values(ascending = False))
# Out:
# Condition
# Used boat              7327
# new boat from stock    2084
# new boat on order       272
# Display Model           119
# dtype: int64

# %%
print(df.groupby('Fuel').size().sort_values(ascending = False))
# Out:
# Fuel
# Diesel      4568
# Unleaded    3040
# Electric      52
# Gas           14
# Hybrid         2
# dtype: int64

# %% [markdown]
# ## Data Clean Up: 'Material' Column

# %%
df.groupby('Material').size().sort_values(ascending = False)
# Out:
# Material
# GRP                    5484
# PVC                    1123
# Steel                   939
# Wood                    235
# Aluminium               229
# Plastic                  77
# Carbon Fiber             30
# Thermoplastic            15
# Hypalon                   5
# Reinforced concrete       1
# Rubber                    1
# dtype: int64

# %% [markdown]
# ## Data Clean Up: Extract 'Country' from 'Location' Column

# %%
df['Location'] = [fix_text(i) for i in df['Location'].fillna('None')]
df['Location'].sample(20)
# Out:
# 5551                               Netherlands » Lelystad
# 7818    France » SAINT-CYPRIEN, France, cap d agde, Fr...
# 120                                       Germany » Wesel
# 5977                Italy » Lago Di Garda Gardasee Italia
# 9885                Germany » Nordrhein-Westfalen » Wesel
# 7849                         France » La Rochelle, France
# 3353                                               Greece
# 5959    Germany » Boote Pfister GmbH Schwebheim / Schw...
# 513                                France » BREST, France
# 3122                       France » PORT NAPOLEON, France
# 9156                  United Kingdom » TROON, Royaume Uni
# 6817                            Italy » Toscana » Toscana
# 5470                                               France
# 6190        Germany » Brandenburg » Berlin / Brandenburg
# 4162                  United Kingdom » Inverkip, Inverkip
# 6601                            France » Cogolin, Cogolin
# 6133                        France » PORNICHET, PORNICHET
# 1561                                         Italy » Lago
# 8414                           France » Marseille, France
# 18                           France » MARTGUES, MARTIGUES
# Name: Location, dtype: object

# %%
df = clean.clean_country(df,"Location", fuzzy_dist=0, report = True)
df = df.rename(columns = {'Location_clean': 'Country'})
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Country Cleaning Report:
# 	9166 values cleaned (92.7%)
# 	88 values unable to be parsed (0.89%), set to NaN
# Result contains 9764 (98.75%) values in the correct format and 124 null values (1.25%)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.groupby('Country').size().sort_values(ascending=False))
# Out:
# Country
# Germany                        1914
# Italy                          1793
# France                         1230
# Switzerland                    1112
# Netherlands                    1054
# Croatia                         814
# Spain                           702
# United Kingdom                  213
# Denmark                         172
# Portugal                        135
# Austria                          88
# Greece                           85
# Malta                            72
# Turkey                           64
# Belgium                          62
# Poland                           40
# Slovenia                         35
# Finland                          35
# Montenegro                       22
# United Arab Emirates             17
# Sweden                           13
# Monaco                           10
# Slovakia                          9
# Russia                            7
# Estonia                           6
# United States                     6
# Lithuania                         5
# Czech Republic                    5
# Cyprus                            5
# Hungary                           4
# Jersey                            3
# Latvia                            3
# Thailand                          3
# Bulgaria                          3
# Ukraine                           2
# Norway                            2
# Netherlands Antilles              2
# Australia                         2
# Taiwan                            1
# Martinique                        1
# Seychelles                        1
# Serbia                            1
# Romania                           1
# Philippines                       1
# Morocco                           1
# Luxembourg                        1
# Lebanon                           1
# Isle of Man                       1
# Ireland                           1
# Gibraltar                         1
# French Southern Territories       1
# Egypt                             1
# Venezuela                         1
# dtype: int64

# %%
df.sample(20)[['Location','Country']]
# Out:
#                                                Location      Country
# 3545                                    Poland » Poland       Poland
# 1164                        Italy » Sardegna » sardegna        Italy
# 8891                            Italy » Liguria » 41100        Italy
# 3471                                     Italy » Naples        Italy
# 3704                                  France » onbekend       France
# 3037                                 Croatia (Hrvatska)      Croatia
# 4998                                 Italy » Adria Meer        Italy
# 683             Italy » Liguria » Moniga del Garda (BS)        Italy
# 3488                       Croatia (Hrvatska) » Croatia      Croatia
# 3104                                             Greece       Greece
# 9257          Germany » Kieler Bucht mit Fehmarn » Kiel      Germany
# 4836       Switzerland » Lake Constance » 8599 Salmsach  Switzerland
# 6278  Netherlands » Verkoophaven IJsseldelta Marina ...  Netherlands
# 7360                                Italy » Mar Tirreno        Italy
# 2219                  Italy » Lombardy, Soiano del Lago        Italy
# 6415                              Germany » Brandenburg      Germany
# 1425                      Netherlands » In verkoophaven  Netherlands
# 4007                 France » VILLENEUVE LOUBET, ITALIE       France
# 1757                     Germany » Neustadt in Holstein      Germany
# 8603                France » La Forêt-Fouesnant, France       France

# %%
countries_check = ['Egypt','Morocco', 'French Southern Territories', 'Netherlands Antilles', 'Gibraltar', 'Jersey', 'United States']
df.loc[df['Country'].isin(countries_check), ['Location', 'Country']]
# Out:
#                                             Location                      Country
# 1825                         United States » Florida                United States
# 1990  French Southern Territories » Port de Beaulieu  French Southern Territories
# 2148            United States » Valencia, États-Unis                United States
# 2982                                Egypt » El Gouna                        Egypt
# 3109                        United Kingdom » Jersey                        Jersey
# 3129                                          Jersey                       Jersey
# 3415                         United States » Florida                United States
# 3617                                   United States                United States
# 3911                        United Kingdom » Jersey                        Jersey
# 4390                                Morocco » Ceuta                       Morocco
# 4435                                       Gibraltar                    Gibraltar
# 5197             United States » Grado, Grado, Grado                United States
# 5903                Netherlands » Omgeving Antwerpen         Netherlands Antilles
# 6090                Netherlands » Omgeving Antwerpen         Netherlands Antilles
# 6550                 United States » Rab, États-Unis                United States

# %%
df.loc[df['Country'].isna(), ['Location','Country']]
# Out:
#                   Location Country
# 260                Rovinij     NaN
# 315            Steinwiesen     NaN
# 494                  Rolle     NaN
# 534            baden baden     NaN
# 554                  Donau     NaN
# ...                    ...     ...
# 9806  Lake Geneva » Founex     NaN
# 9811           Rheinfelden     NaN
# 9830               Barssel     NaN
# 9842          Welschenrohr     NaN
# 9843                  Thun     NaN
#
# [124 rows x 2 columns]

# %%
gn = geocoders.Nominatim(user_agent="datacamp-cert")
geocode = RateLimiter(gn.geocode, min_delay_seconds=1)

# Thal, Switzerland
place, (lat, lng) = gn.geocode("België, Zulte", language = 'en')
print(place)
# Out:
# Zulte, Gent, East Flanders, Flanders, 9870, Belgium

# %%
df_geocoded = df.loc[df['Country'].isna()]
df_geocoded['Location'] = df_geocoded['Location'].str.replace('\d+', '')
df_geocoded['Location'] = df_geocoded['Location'].str.replace('»', '')
df_geocoded['Location'] = df_geocoded['Location'].str.strip()
df_geocoded['Location'] = df_geocoded['Location'].str.replace('None','')

df_geocoded['Location_geocoded'] = df_geocoded['Location'].apply(partial(geocode, language='en'))

#df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df_geocoded[['Location', 'Location_geocoded']]
# Out:
#                  Location                                  Location_geocoded
# 260               Rovinij                                               None
# 315           Steinwiesen  (Steinwiesen, Landkreis Kronach, Bavaria, 9634...
# 494                 Rolle  (Rolle, District de Nyon, Vaud, 1180, Switzerl...
# 534           baden baden  (Baden-Baden, Baden-Württemberg, Germany, (48....
# 554                 Donau  (Danube, 5th district, Budapest, Central Hunga...
# ...                   ...                                                ...
# 9806  Lake Geneva  Founex                                               None
# 9811          Rheinfelden  (Rheinfelden, Bezirk Rheinfelden, Aargau, 4310...
# 9830              Barssel  (Barßel, Cloppenburg district, Lower Saxony, 2...
# 9842         Welschenrohr  (Welschenrohr-Gänsbrunnen, Bezirk Thal, Amtei ...
# 9843                 Thun  (Thun, Thun administrative district, Oberland ...
#
# [124 rows x 2 columns]

# %%
df_geocoded['Address_geocoded'] = df_geocoded.Location_geocoded.apply( lambda x: x.address if not pd.isnull(x) else x)
df_geocoded['Address_geocoded']
# Out:
# 260                                                  None
# 315     Steinwiesen, Landkreis Kronach, Bavaria, 96349...
# 494      Rolle, District de Nyon, Vaud, 1180, Switzerland
# 534               Baden-Baden, Baden-Württemberg, Germany
# 554     Danube, 5th district, Budapest, Central Hungar...
#                               ...
# 9806                                                 None
# 9811    Rheinfelden, Bezirk Rheinfelden, Aargau, 4310,...
# 9830    Barßel, Cloppenburg district, Lower Saxony, 26...
# 9842    Welschenrohr-Gänsbrunnen, Bezirk Thal, Amtei T...
# 9843    Thun, Thun administrative district, Oberland a...
# Name: Address_geocoded, Length: 124, dtype: object

# %%
df_geocoded['Country_geocoded'] = df_geocoded['Address_geocoded'].str.rsplit(',').str[-1]
df_geocoded['Country_geocoded'] = df_geocoded['Address_geocoded'].str.strip()
df_geocoded[['Location', 'Address_geocoded', 'Country_geocoded']]
# Out:
#                  Location  ...                                   Country_geocoded
# 260               Rovinij  ...                                               None
# 315           Steinwiesen  ...  Steinwiesen, Landkreis Kronach, Bavaria, 96349...
# 494                 Rolle  ...   Rolle, District de Nyon, Vaud, 1180, Switzerland
# 534           baden baden  ...            Baden-Baden, Baden-Württemberg, Germany
# 554                 Donau  ...  Danube, 5th district, Budapest, Central Hungar...
# ...                   ...  ...                                                ...
# 9806  Lake Geneva  Founex  ...                                               None
# 9811          Rheinfelden  ...  Rheinfelden, Bezirk Rheinfelden, Aargau, 4310,...
# 9830              Barssel  ...  Barßel, Cloppenburg district, Lower Saxony, 26...
# 9842         Welschenrohr  ...  Welschenrohr-Gänsbrunnen, Bezirk Thal, Amtei T...
# 9843                 Thun  ...  Thun, Thun administrative district, Oberland a...
#
# [124 rows x 3 columns]

# %%
df_geocoded['Country_geocoded'].unique()
# Out:
# array([None, 'Steinwiesen, Landkreis Kronach, Bavaria, 96349, Germany',
#        'Rolle, District de Nyon, Vaud, 1180, Switzerland',
#        'Baden-Baden, Baden-Württemberg, Germany',
#        'Danube, 5th district, Budapest, Central Hungary, 1007, Hungary',
#        'Travemünde, Lübeck, Schleswig-Holstein, 23570, Germany',
#        'Stralsund, Vorpommern-Rügen, Mecklenburg-Vorpommern, Germany',
#        'Rostock, Mecklenburg-Vorpommern, Germany',
#        'Lake Constance, Bodenseekreis, Baden-Württemberg, Germany',
#        'Lake Geneva Overlook, Chemin de Machéry, Pregny, Pregny-Chambésy, Geneva, 1292, Switzerland',
#        'Split, Grad Split, Split-Dalmatia County, Croatia',
#        'Lake Maggiore, Verbano-Cusio-Ossola, Piedmont, 28900, Italy',
#        'Zulte, Gent, East Flanders, Flanders, 9870, Belgium',
#        'Donau, Kagers, Straubing, Bavaria, 94315, Germany',
#        'Rügen, Mecklenburg-Vorpommern, Germany',
#        'Zevenbergen, Moerdijk, North Brabant, Netherlands',
#        'Faoug, District de la Broye-Vully, Vaud, 1595, Switzerland',
#        'Beilngries, Landkreis Eichstätt, Bavaria, 92339, Germany',
#        'Geneva Lake, Lake Geneva, Town of Linn, Walworth County, Wisconsin, 53125, United States',
#        'Marina Punat, 17. travnja, Punat, Općina Punat, Primorje-Gorski Kotar County, 51521, Croatia',
#        'Italy', 'Brandenburg, Germany',
#        'Waren (Müritz), Lloydstraße, Werdersiedlung, Waren (Müritz), Mecklenburgische Seenplatte, Mecklenburg-Vorpommern, 17192, Germany',
#        'Ostseeweg, Neustadt in Holstein, Ostholstein, Schleswig-Holstein, 23730, Germany',
#        'Adria, Rovigo, Veneto, 45011, Italy',
#        'Majorca, Balearic Islands, Spain',
#        'Annecy, Upper Savoy, Auvergne-Rhône-Alpes, Metropolitan France, France',
#        'Izola / Isola, Upravna enota Izola / Unità amministrativa Isola, Slovenia',
#        'Traunstein, Landkreis Traunstein, Bavaria, 83278, Germany',
#        'Novi Vinodolski, Grad Novi Vinodolski, Primorje-Gorski Kotar County, 51250, Croatia',
#        'Dalmatien, 49, August-Haas-Straße, Neu-Longerich, Longerich, Nippes, Cologne, North Rhine-Westphalia, 50737, Germany',
#        'Lake Garda, Brescia, Lombardy, Italy',
#        'Opwijk, Halle-Vilvoorde, Flemish Brabant, Flanders, 1745, Belgium',
#        'Wurster Nordseeküste, Landkreis Cuxhaven, Lower Saxony, 27639, Germany',
#        'Büdelsdorf, Rendsburg-Eckernförde, Schleswig-Holstein, 24782, Germany',
#        'Gemeinde Neusiedl am See, Bezirk Neusiedl am See, Burgenland, 7100, Austria',
#        'Lake Geneva Hotel, 77, Route de Suisse, Versoix, Geneva, 1290, Switzerland',
#        'Platja de Calanova, Sant Agustí, Palma, Balearic Islands, Palma',
#        'Avenches, District de la Broye-Vully, Vaud, 1580, Switzerland',
#        'Heilbronn, Baden-Württemberg, Germany',
#        'Espa¤a, La Trinidad, Comayagua, Honduras',
#        'Krk, Primorje-Gorski Kotar County, Croatia',
#        'Ibiza, Balearic Islands, Spain',
#        'Katwijk, South Holland, Netherlands',
#        'Lommel, Maaseik, Limburg, Flanders, 3920, Belgium',
#        'Wijdenes, Drechterland, North Holland, Netherlands',
#        'Via Lago Maggiore, Castelletto sopra Ticino, Novara, Piedmont, 28053, Italy',
#        'Bremen, Free Hanseatic City of Bremen, Germany',
#        'Bielefeld, North Rhine-Westphalia, Germany',
#        'Porto Rotondo, Olbia, Nord-Est Sardegna, Sardinia, 07026, Italy',
#        'Ostsee-Stellplatz, Querdeich, Zingst, Vorpommern-Rügen, Mecklenburg-Vorpommern, 18374, Germany',
#        'Berlin-Wannsee, Reichsbahnstraße, Wannsee, Steglitz-Zehlendorf, Berlin, 14109, Germany',
#        'Tuscany, Italy',
#        'Lago Maggiore, 4, Via Lido, Tenero, Tenero-Contra, Circolo della Navegna, Distretto di Locarno, Ticino, 6598, Switzerland',
#        'Camping Buochs-Vierwaldstättersee, 4, Seefeldstrasse, Buochs, Nidwalden, 6374, Switzerland',
#        'Donau, Aschach an der Donau, Bezirk Eferding, Upper Austria, 4082, Austria',
#        'Gemeinde Fußach, Bezirk Bregenz, Vorarlberg, 6972, Austria',
#        'Angera, Varese, Lombardy, 21021, Italy',
#        'Lausanne Court, Lake Como, Town of Geneva, Walworth County, Wisconsin, 53191, United States',
#        'Thalwil, Bezirk Horgen, Zurich, 8800, Switzerland',
#        'Juelsminde Havn og Marina, Havnegade, Juelsminde, Hedensted Municipality, Central Denmark Region, 7130, Denmark',
#        'Rheinfelden, Bezirk Rheinfelden, Aargau, 4310, Switzerland',
#        'Barßel, Cloppenburg district, Lower Saxony, 26676, Germany',
#        'Welschenrohr-Gänsbrunnen, Bezirk Thal, Amtei Thal-Gäu, Solothurn, 4716, Switzerland',
#        'Thun, Thun administrative district, Oberland administrative region, Bern, Switzerland'],
#       dtype=object)

# %%
df = df.join(df_geocoded['Country_geocoded'],lsuffix='', rsuffix='')
df['Country'] = df[['Country', 'Country_geocoded']].bfill(axis=1).iloc[:, 0]

# %%
df.drop(['Country_geocoded'], axis = 1,inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9888 entries, 0 to 9887
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Price                        9888 non-null   object
#  1   Boat Type                    9888 non-null   object
#  2   Manufacturer                 9888 non-null   object
#  3   Type                         9882 non-null   object
#  4   Year Built                   9888 non-null   int64
#  5   Length                       9879 non-null   float64
#  6   Width                        9832 non-null   float64
#  7   Material                     8139 non-null   object
#  8   Location                     9888 non-null   object
#  9   Number of views last 7 days  9888 non-null   int64
#  10  Currency                     9888 non-null   object
#  11  Amount                       9888 non-null   float64
#  12  Price (USD)                  9888 non-null   float64
#  13  Boat Type - Main             9888 non-null   object
#  14  Boat Type - Subtype          9888 non-null   object
#  15  Condition                    9802 non-null   object
#  16  Fuel                         7676 non-null   object
#  17  Country                      9835 non-null   object
# dtypes: float64(4), int64(2), object(12)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Data Clean Up: Extract 'Region' from 'Location' Column

# %%
df['Location_reg'] = df.apply(lambda x: x['Location'].replace(str(x['Country']), '') , axis=1)
df['Location_reg'] = df['Location_reg'].str.strip('» ')

df['Location_reg_1'] = df['Location_reg'].map(lambda x: x.split('»')[0])
df['Location_reg_2'] = df['Location_reg'].map(lambda x: x.split('»')[1] if len(x.split('»')) > 1 else '')

#df['Location_reg'] = df['Location_reg'].str.replace('\d+', '')
#df['Location_reg_1'] = df['Location_reg'].map(lambda x: x.split('»')[0])
#df['Location_reg_2'] = df['Location_reg'].str.split('»')[1]
#df['Location_reg_1'] = df['Location_reg'].str.strip()
#df_geocoded['Location'] = df_geocoded['Location'].str.replace('None','')
#df['Location_reg_1']
df[['Location','Country','Location_reg_1', 'Location_reg_2']]
# Out:
#                                      Location  ... Location_reg_2
# 0         Switzerland » Lake Geneva » Vésenaz  ...        Vésenaz
# 1                      Germany » Bönningstedt  ...
# 2     Switzerland » Lake of Zurich » Stäfa ZH  ...       Stäfa ZH
# 3                         Denmark » Svendborg  ...
# 4                  Germany » Bayern » München  ...        München
# ...                                       ...  ...            ...
# 9883   Switzerland » Lago Maggiore » Riazzino  ...       Riazzino
# 9884              Germany » Hamburg » HAMBURG  ...        HAMBURG
# 9885    Germany » Nordrhein-Westfalen » Wesel  ...          Wesel
# 9886                     Italy » Dormelletto   ...
# 9887       Switzerland » Brienzersee » Brienz  ...         Brienz
#
# [9888 rows x 4 columns]

# %%
df['Location_reg_1'].nunique()
# Out:
# 1768

# %% [markdown]
# ## Data Clean Up -> Numeric Columns

# %%
df[df['Year Built'] == 0].sort_values('Year Built')

# %%
df[df['Length'] < 2 ].sort_values('Length')

# %%
df[df['Width'] < 2 ].sort_values('Width')

# %%
df_clean = df.drop(['Price', 'Type', 'Location'], axis = 1)
df_clean['Year Built'] = df_clean['Year Built'].replace(0, np.nan)
df_clean.replace('None', np.nan, inplace = True)
df_clean.fillna(np.nan)
df_clean.info()

# %%
df_clean.describe()

# %% [markdown]
# ## Data Clean Up: Outliers

# %%
fig, axes = plt.subplots(1,4,figsize=(15,5))
sns.violinplot(df_clean['Length'], inner = 'box', ax = axes[0])
sns.violinplot(df_clean['Width'], inner = 'box', ax = axes[1])
sns.violinplot(df_clean['Number of views last 7 days'], inner = 'box', ax = axes[2])
sns.violinplot(df_clean['Price (USD)'], inner = 'box', ax = axes[3])

# %%
fig, axes = plt.subplots(1,4,figsize=(15,5))
sns.histplot(df_clean['Length'], ax = axes[0])
sns.histplot(df_clean['Width'], ax = axes[1])
sns.histplot(df_clean['Number of views last 7 days'], ax = axes[2])
sns.histplot(df_clean['Price (USD)'], ax = axes[3])

# %%
fig, axes = plt.subplots(1,4,figsize=(15,5))
sns.histplot(df_clean['Length'], ax = axes[0], log_scale = True)
sns.histplot(df_clean['Width'], ax = axes[1], log_scale = True)
sns.histplot(df_clean['Number of views last 7 days'], ax = axes[2], log_scale = True)
sns.histplot(df_clean['Price (USD)'], ax = axes[3], log_scale = True)

# %% [markdown]
# ## Data Imputation

# %%
df_clean.info()

# %%
msno.matrix(df_clean)

# %%
msno.heatmap(df_clean)

# %%
msno.dendrogram(df_clean)

# %%
cat_encode = OrdinalEncoder()
cat_cols = ['Boat Type', 'Manufacturer', 'Material', 'Currency', 'Condition', 'Fuel', 'Country' ]
df_enc = df_clean.copy()
df_enc[cat_cols] = pd.DataFrame(cat_encode.fit_transform(df_clean[cat_cols]), columns = df_clean[cat_cols].columns)
df_enc.head()

# %%
cat_encode.categories_

# %%
imp = IterativeImputer(estimator = RandomForestRegressor(), missing_values= np.nan, max_iter=30, random_state=0)
imp.fit(df_enc)

# %%
df_imp = pd.DataFrame(imp.transform(df_enc), columns = df_enc.columns )

# %%
df_imp.describe()

# %%
df_enc.describe()

# %%
df_clean_impd = df_imp.copy()
df_clean_impd[cat_cols] = pd.DataFrame(cat_encode.inverse_transform(df_clean_impd[cat_cols]), columns = cat_cols)
df_clean_impd.info()

# %%
[df_clean_impd['Country'].nunique(), df_clean['Country'].nunique()]

# %%
# Winsorize Outliers 
outlier_columns = ['Length', 'Width', 'Number of views last 7 days', 'Price (USD)']
limits = [[0.002, 0.001], [0.004, 0.005], [0.0001, 0.001], [0.00001, 0.001]]
df_clean_impd_wind = df_clean_impd.copy()

for i in range(4):
    current_col = outlier_columns[i]
    current_lim = limits[i] 
    df_clean_impd_wind[current_col] = pd.DataFrame(stats.mstats.winsorize(df_clean_impd_wind[current_col], limits = current_lim))

df_clean_impd_wind.describe()

# %%
df_clean_impd_wind.drop(['Amount', 'Currency'], axis = 1, inplace = True)
df_clean_impd_wind.rename(columns = {'Number of views last 7 days' : 'Views (last 7 days)', 'Year Built': 'Year'}, inplace=True)

# %%
fig, axes = plt.subplots(1,4,figsize=(20,7))
sns.histplot(df_clean_impd_wind['Length'], ax = axes[0], log_scale = True)
sns.histplot(df_clean_impd_wind['Width'], ax = axes[1], log_scale = True)
sns.histplot(df_clean_impd_wind['Views (last 7 days)'], ax = axes[2], log_scale = True)
sns.histplot(df_clean_impd_wind['Price (USD)'], ax = axes[3], log_scale = True)

# %%
fig, axes = plt.subplots(1,4,figsize=(20,7))
sns.violinplot(df_clean_impd_wind['Length'], inner = 'box', ax = axes[0])
sns.violinplot(df_clean_impd_wind['Width'], inner = 'box', ax = axes[1])
sns.violinplot(df_clean_impd_wind['Views (last 7 days)'], inner = 'box', ax = axes[2])
sns.violinplot(df_clean_impd_wind['Price (USD)'], inner = 'box', ax = axes[3])

# %%
df_clean_impd_wind['Log(Views_7d)'] = np.log10(df_clean_impd_wind['Views (last 7 days)'])
df_clean_impd_wind['Log(Length)'] = np.log10(df_clean_impd_wind['Length'])
df_clean_impd_wind['Log(Width)'] = np.log10(df_clean_impd_wind['Width'])
df_clean_impd_wind['Log(Price)'] = np.log10(df_clean_impd_wind['Price (USD)'])

# %% [markdown]
# Note - Perfrom Box Cogg transformation to reduce these distributions to a normal one

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Target Variable - Views (7 days)

# %%
sns.histplot(df_clean_impd_wind['Views (last 7 days)'])
plt.show()

# %%
num_columns = ['Length', 'Width', 'Views (last 7 days)', 'Price (USD)']
num_cols = df_clean_impd_wind[num_columns]
sns.heatmap(num_cols.corr(),annot=True).set(title='The Correlation Heatmap between Numeric Variables')

# %%
sns.pairplot(df_clean_impd_wind)
plt.show()

# %%
fig, axes = plt.subplots(1,4,figsize=(15,5))
sns.scatterplot(y = df_clean_impd_wind['Log(Views_7d)'], x = np.log10(df_clean_impd_wind['Length']), ax=axes[0])
sns.scatterplot(y = df_clean_impd_wind['Log(Views_7d)'], x = np.log10(df_clean_impd_wind['Width']), ax=axes[1])
sns.scatterplot(y = df_clean_impd_wind['Log(Views_7d)'], x = df_clean_impd_wind['Year'], ax=axes[2])
sns.scatterplot(y = df_clean_impd_wind['Log(Views_7d)'], x = np.log10(df_clean_impd_wind['Price (USD)']), ax=axes[3])

# %% [markdown]
# This might be a problem for the model as there seems to be no notable dependency on the numeric variables

# %%
sns.scatterplot( data = df_clean_impd_wind, x = 'Year', y = 'Log(Price)', size = 'Views (last 7 days)', alpha = 0.1)

# %% [markdown]
# # Model Fitting and Evaluation
#
# ### Prepare Data for Modeling
# - Normalize features
# - Convert categorical values into numeric features
# - Split data into training and test set

# %%
df_clean_impd_wind.info()

# %%
df_model = df_clean_impd_wind.copy()
cat_encode = OrdinalEncoder()
cat_cols = ['Boat Type', 'Manufacturer', 'Material', 'Condition', 'Fuel', 'Country' ]


df_model[cat_cols] = cat_encode.fit_transform(df_model[cat_cols])

# %%
df_model.columns

# %%
feature_cols = ['Boat Type', 'Manufacturer', 'Year', 'Material', 'Condition', 'Fuel', 'Country', 'Log(Length)', 'Log(Width)', 'Log(Price)']
X = df_model[feature_cols]           # Features
y = df_model['Log(Views_7d)']  # Target variable

# %%
# define the scaler 
scaler = PowerTransformer()
# fit and transform the train set
#X[['Year','Length', 'Width', 'Price (USD)', 'Log(Length)', 'Log(Width)', 'Log(Price)']] = scaler.fit_transform(X[['Year','Length', 'Width', 'Price (USD)', 'Log(Length)', 'Log(Width)', 'Log(Price)']])
X[['Year', 'Log(Length)', 'Log(Width)', 'Log(Price)']] = scaler.fit_transform(X[['Year', 'Log(Length)', 'Log(Width)', 'Log(Price)']])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Linear Regression Model

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)
print('Linear Regression r2_score: ',r2_score(y_test,y_pred))
print('Linear Regression Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,y_pred)))

# %%
resultdict = {}
for i in range(len(feature_cols)):
    resultdict[feature_cols[i]] = lr.coef_[i]
    
plt.bar(resultdict.keys(),resultdict.values())
plt.xticks(rotation='vertical')
plt.title('Feature Importance in Linear Regression Model');

# %% [markdown]
# ### Decision Tree Regression Model

# %%
tree = DecisionTreeRegressor(max_depth=12,min_samples_split=2,random_state=42)
tree.fit(X_train,y_train)
y_pred2 = tree.predict(X_test)

# %%
d_r2 = tree.score(X_test, y_test)
print("Decision Tree Regressor R-squared: {}".format(d_r2))

d_mse = mean_squared_error(y_pred2, y_test)
d_rmse = np.sqrt(d_mse)
print("Decision Tree Regressor RMSE: {}".format(d_rmse))

# %% [markdown]
# ### Random Forest Regresison Model

# %%
forest = RandomForestRegressor() #max_depth=50,min_samples_split=2,random_state=42
forest.fit(X_train,y_train)
y_pred2 = forest.predict(X_test)

# %%
d_r2 = forest.score(X_test, y_test)
print("Decision Tree Regressor R-squared: {}".format(d_r2))

d_mse = mean_squared_error(y_pred2, y_test)
d_rmse = np.sqrt(d_mse)
print("Decision Tree Regressor RMSE: {}".format(d_rmse))

# %%
resultdict = {}
for i in range(len(feature_cols)):
    resultdict[feature_cols[i]] = forest.feature_importances_[i]
    
plt.bar(resultdict.keys(),resultdict.values())
plt.xticks(rotation='vertical')
plt.title('Feature Importance in Random Forest Regression Model');
