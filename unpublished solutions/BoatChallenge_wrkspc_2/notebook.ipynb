# %% [markdown]
# # Data Scientist Professional Practical Exam
#
# ### Company Background
#
# Nearly New Nautical is a website that allows users to advertise their used boats for sale. When users list their boat, they have to provide a range of information about their boat. Boats that get lots of views bring more traffic to the website, and more potential customers.
#
# To boost traffic to the website, the product manager wants to prevent listing boats that do not receive many views.
#
#
#
#
# ### Customer Question
#
# The product manager wants to know the following:
# - Can you predict the number of views a listing will receive based on the boat's features?
#
#
#
# ### Success Criteria
#
# The product manager would consider using your model if, on average, the predictions were only 50% off of the true number of views a listing would receive.
#
#
# ### Dataset
#
# The data you will use for this analysis can be accessed here: `"data/boat_data.csv"`

# %% [markdown]
# # Import and Install Modules

# %%
# Install modules not preinstalled in DC Workspaces
# !pip install forex_python
# !pip install ftfy
# Out:
# Collecting forex_python
#   Downloading forex_python-1.8-py3-none-any.whl (8.2 kB)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 14.6 MB/s eta 0:00:00
# Collecting simplejson
#   Downloading simplejson-3.18.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.5/135.5 kB 32.9 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 37.9 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 17.8 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 44.2 MB/s eta 0:00:00
# Installing collected packages: urllib3, simplejson, idna, charset-normalizer, certifi, requests, forex_python
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# redshift-connector 2.0.908 requires requests<2.28.1,>=2.23.0, but you have requests 2.28.1 which is incompatible.
# Successfully installed certifi-2022.12.7 charset-normalizer-2.1.1 forex_python-1.8 idna-3.4 requests-2.28.1 simplejson-3.18.1 urllib3-1.26.13
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 14.0 MB/s eta 0:00:00
# Collecting wcwidth>=0.2.5
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Installing collected packages: wcwidth, ftfy
# Successfully installed ftfy-6.1.1 wcwidth-0.2.5
# WARNING: Target directory /home/repl/.local/lib/python3.8/site-packages/bin already exists. Specify --upgrade to force replacement.

# %%
# Import modules
import pandas as pd
import numpy as np
import chardet as ch 
from forex_python.converter import CurrencyRates
from ftfy import fix_and_explain, fix_text
import datetime

import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import r2_score,mean_squared_error
plt.style.use('ggplot')

# %% [markdown]
# # Load Data

# %%
with open('data/boat_data.csv', 'rb') as file:             # check CSV file encoding to reduce reding errors and data cleanup
    print(ch.detect(file.read()))
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
df = pd.read_csv('data/boat_data.csv', encoding = "utf-8")     # load data into dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9888 entries, 0 to 9887
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Price                        9888 non-null   object
#  1   Boat Type                    9888 non-null   object
#  2   Manufacturer                 8550 non-null   object
#  3   Type                         9882 non-null   object
#  4   Year Built                   9888 non-null   int64
#  5   Length                       9879 non-null   float64
#  6   Width                        9832 non-null   float64
#  7   Material                     8139 non-null   object
#  8   Location                     9852 non-null   object
#  9   Number of views last 7 days  9888 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 772.6+ KB

# %%
df.describe()
# Out:
#         Year Built       Length        Width  Number of views last 7 days
# count  9888.000000  9879.000000  9832.000000                  9888.000000
# mean   1893.192860    11.570017     3.520124                   149.160801
# std     460.201582     6.002820     1.220534                   151.819752
# min       0.000000     1.040000     0.010000                    13.000000
# 25%    1996.000000     7.470000     2.540000                    70.000000
# 50%    2007.000000    10.280000     3.330000                   108.000000
# 75%    2017.000000    13.930000     4.250000                   172.000000
# max    2021.000000   100.000000    25.160000                  3263.000000

# %%
df.head(10)
# Out:
#        Price  ... Number of views last 7 days
# 0   CHF 3337  ...                         226
# 1   EUR 3490  ...                          75
# 2   CHF 3770  ...                         124
# 3  DKK 25900  ...                          64
# 4   EUR 3399  ...                          58
# 5   CHF 3650  ...                         132
# 6   CHF 3600  ...                         474
# 7  DKK 24800  ...                         134
# 8   EUR 3333  ...                          45
# 9   EUR 3300  ...                         180
#
# [10 rows x 10 columns]

# %%
df.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 df.nunique()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Data Clean Up

# %% [markdown]
# To Dos:
# * 	\[Price\]:
# 	*  Parse Price into 'Currency' + 'Amount' columns 		✔
# 	*  Convert to Euros or USD  						✔
# * 	\[Boat Type\]:
# 	* 	Search & Group Similar Categories
# * 	\[Manufacturer\]:
# 	*	Remove "power boats"  							✔
# 	* 	Clean up characters 							✔
# 	* 	Fuzzy match manufacturers to reduce counts
# * 	\[Type\]:
# 	* 	Parse Column into 'Condition' + 'Fuel Type' columns
#     * Separate into: New / Used / Display, Diesel / Unleaded / Electric / Gas
# * 	\[Material\]:
# 	* 	()
# * 	\[Location\]:
# 	* 	Parse Country, Region & City
# 	* 	Correct Mispelled Words / Characters

# %% [markdown]
# ### Data Clean Up

# %%
df[['Currency', 'Amount']] = df.Price.str.split(" ", expand=True )         # Split 'Price' into 'Currency' & 'Amount' 
print(df.Amount.isnull().values.any())                                     # Check there are non nulls in 'Amount'
print(df.Currency.isnull().values.any())                                   # Check there are non nulls in 'Currency'
print(df.Currency.unique())
# Out:
# False
# False
# ['CHF' 'EUR' 'DKK' 'Â£']

# %%
df['Currency'] = df['Currency'].str.replace('Â£', 'GBP')                   # Clean up British Pound currency chars
print(df.Currency.unique())
# Out:
# ['CHF' 'EUR' 'DKK' 'GBP']

# %%
df.Amount.str.isdigit().all()                       # Check that 'Amount' only contains numeric chars (no '.' or ',')
# Out:
# True

# %%
df['Amount'] = df['Amount'].astype('float64')         # Convert 'Amount' to numeric

# %%
# The following approach is too slow, as it has to perform 9k get requests

# curr = CurrencyRates()
# df['Amount (USD)'] = df.apply( lambda x: curr.convert( x.Currency, 'USD', x.Amount), axis = 1)

# %%
curr = CurrencyRates()
currencies = df.Currency.unique()
conversion_date = datetime.datetime(2023, 1, 3)

rates = [curr.convert(i, 'USD', 1, conversion_date) for i in currencies]
rates_to_USD = dict(zip(currencies, rates))

print(rates_to_USD)
# Out:
# {'CHF': 1.0674157303370786, 'EUR': 1.0545, 'DKK': 0.1417910447761194, 'GBP': 1.1976421951662728}

# %%
df['Price (USD)'] = round(df['Amount'] * df['Currency'].map(rates_to_USD), 2)

# %%
t = df['Boat Type'].unique()
sorted(t)
# Out:
# ['Bowrider',
#  'Bowrider,Cabin Boat,Deck Boat',
#  'Bowrider,Center console boat,Sport Boat',
#  'Bowrider,Classic',
#  'Bowrider,Deck Boat,Water ski',
#  'Bowrider,Motor Yacht,Sport Boat',
#  'Bowrider,Motor Yacht,Wakeboard/Wakesurf',
#  'Bowrider,Sport Boat,Wakeboard/Wakesurf',
#  'Bowrider,Wakeboard/Wakesurf',
#  'Cabin Boat',
#  'Cabin Boat,Classic',
#  'Cabin Boat,Classic,Flybridge',
#  'Cabin Boat,Classic,Motor Yacht',
#  'Cabin Boat,Classic,Passenger boat',
#  'Cabin Boat,Classic,Trawler',
#  'Cabin Boat,Fishing Boat',
#  'Cabin Boat,Fishing Boat,House Boat',
#  'Cabin Boat,Fishing Boat,Pilothouse',
#  'Cabin Boat,Fishing Boat,Sport Boat',
#  'Cabin Boat,Flybridge',
#  'Cabin Boat,Flybridge,Motor Yacht',
#  'Cabin Boat,Hardtop',
#  'Cabin Boat,Hardtop,Motor Yacht',
#  'Cabin Boat,Hardtop,Sport Boat',
#  'Cabin Boat,Hardtop,Trawler',
#  'Cabin Boat,House Boat',
#  'Cabin Boat,House Boat,Trawler',
#  'Cabin Boat,Motor Yacht',
#  'Cabin Boat,Motor Yacht,Offshore Boat',
#  'Cabin Boat,Motor Yacht,Sport Boat',
#  'Cabin Boat,Motor Yacht,Trawler',
#  'Cabin Boat,Pilothouse',
#  'Cabin Boat,Pilothouse,Sport Boat',
#  'Cabin Boat,Sport Boat',
#  'Cabin Boat,Sport Boat,Wakeboard/Wakesurf',
#  'Cabin Boat,Sport Boat,Water ski',
#  'Cabin Boat,Trawler',
#  'Catamaran',
#  'Center console boat',
#  'Center console boat,Classic',
#  'Center console boat,Deck Boat,Sport Boat',
#  'Center console boat,Deck Boat,Working Boat',
#  'Center console boat,Fishing Boat,Sport Boat',
#  'Center console boat,Sport Boat',
#  'Center console boat,Sport Boat,Water ski',
#  'Classic',
#  'Classic,Deck Boat',
#  'Classic,Fishing Boat',
#  'Classic,Fishing Boat,Working Boat',
#  'Classic,Flybridge',
#  'Classic,Hardtop,Motor Yacht',
#  'Classic,House Boat,Motor Yacht',
#  'Classic,House Boat,Passenger boat',
#  'Classic,Launch',
#  'Classic,Mega Yacht',
#  'Classic,Motor Yacht',
#  'Classic,Motor Yacht,Passenger boat',
#  'Classic,Motor Yacht,Sport Boat',
#  'Classic,Motor Yacht,Water ski',
#  'Classic,Motorsailer',
#  'Classic,Pontoon Boat',
#  'Classic,Pontoon Boat,Trawler',
#  'Classic,Runabout',
#  'Classic,Runabout,Sport Boat',
#  'Classic,Runabout,Trawler',
#  'Classic,Sport Boat',
#  'Classic,Sport Boat,Trawler',
#  'Classic,Sport Boat,Water ski',
#  'Classic,Trawler',
#  'Classic,Working Boat',
#  'Deck Boat',
#  'Deck Boat,Pilothouse,Sport Boat',
#  'Deck Boat,Water ski',
#  'Fishing Boat',
#  'Fishing Boat,Flybridge,Trawler',
#  'Fishing Boat,Hardtop,Pilothouse',
#  'Fishing Boat,Launch,Motor Yacht',
#  'Fishing Boat,Passenger boat,Sport Boat',
#  'Fishing Boat,Pilothouse',
#  'Fishing Boat,Sport Boat',
#  'Flybridge',
#  'Flybridge,Hardtop,Motor Yacht',
#  'Flybridge,Motor Yacht',
#  'Flybridge,Pilothouse',
#  'Hardtop',
#  'Hardtop,Mega Yacht,Motor Yacht',
#  'Hardtop,Motor Yacht',
#  'Hardtop,Motor Yacht,Sport Boat',
#  'Hardtop,Sport Boat',
#  'House Boat',
#  'House Boat,Motor Yacht',
#  'House Boat,Motor Yacht,Trawler',
#  'House Boat,Sport Boat,Trawler',
#  'Ketch',
#  'Launch',
#  'Mega Yacht',
#  'Motor Yacht',
#  'Motor Yacht,Sport Boat',
#  'Motor Yacht,Sport Boat,Trawler',
#  'Motor Yacht,Sport Boat,Water ski',
#  'Motor Yacht,Trawler',
#  'Motor Yacht,Wakeboard/Wakesurf',
#  'Motorsailer',
#  'Offshore Boat',
#  'Offshore Boat,Pilothouse',
#  'Offshore Boat,Sport Boat',
#  'Passenger boat',
#  'Passenger boat,Runabout,Sport Boat',
#  'Passenger boat,Working Boat',
#  'Pilothouse',
#  'Pilothouse,Sport Boat',
#  'Pontoon Boat',
#  'RIB',
#  'Runabout',
#  'Runabout,Sport Boat',
#  'Runabout,Sport Boat,Water ski',
#  'Sport Boat',
#  'Sport Boat,Wakeboard/Wakesurf',
#  'Sport Boat,Wakeboard/Wakesurf,Water ski',
#  'Sport Boat,Water ski',
#  'Sport Boat,Working Boat',
#  'Trawler',
#  'Wakeboard/Wakesurf',
#  'Wakeboard/Wakesurf,Water ski',
#  'Water ski',
#  'Working Boat']

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.groupby('Boat Type').size())
# Out:
# Boat Type
# Bowrider                                        301
# Bowrider,Cabin Boat,Deck Boat                     1
# Bowrider,Center console boat,Sport Boat           1
# Bowrider,Classic                                  1
# Bowrider,Deck Boat,Water ski                      1
# Bowrider,Motor Yacht,Sport Boat                   1
# Bowrider,Motor Yacht,Wakeboard/Wakesurf           1
# Bowrider,Sport Boat,Wakeboard/Wakesurf            2
# Bowrider,Wakeboard/Wakesurf                       1
# Cabin Boat                                      585
# Cabin Boat,Classic                                9
# Cabin Boat,Classic,Flybridge                      1
# Cabin Boat,Classic,Motor Yacht                    3
# Cabin Boat,Classic,Passenger boat                 1
# Cabin Boat,Classic,Trawler                        1
# Cabin Boat,Fishing Boat                           2
# Cabin Boat,Fishing Boat,House Boat                1
# Cabin Boat,Fishing Boat,Pilothouse                1
# Cabin Boat,Fishing Boat,Sport Boat                1
# Cabin Boat,Flybridge                              3
# Cabin Boat,Flybridge,Motor Yacht                  2
# Cabin Boat,Hardtop                                2
# Cabin Boat,Hardtop,Motor Yacht                    1
# Cabin Boat,Hardtop,Sport Boat                     1
# Cabin Boat,Hardtop,Trawler                        1
# Cabin Boat,House Boat                             3
# Cabin Boat,House Boat,Trawler                     1
# Cabin Boat,Motor Yacht                           10
# Cabin Boat,Motor Yacht,Offshore Boat              1
# Cabin Boat,Motor Yacht,Sport Boat                 7
# Cabin Boat,Motor Yacht,Trawler                    1
# Cabin Boat,Pilothouse                             1
# Cabin Boat,Pilothouse,Sport Boat                  1
# Cabin Boat,Sport Boat                             9
# Cabin Boat,Sport Boat,Wakeboard/Wakesurf          1
# Cabin Boat,Sport Boat,Water ski                   1
# Cabin Boat,Trawler                                3
# Catamaran                                        26
# Center console boat                             369
# Center console boat,Classic                       2
# Center console boat,Deck Boat,Sport Boat          1
# Center console boat,Deck Boat,Working Boat        1
# Center console boat,Fishing Boat,Sport Boat       1
# Center console boat,Sport Boat                    2
# Center console boat,Sport Boat,Water ski          1
# Classic                                          59
# Classic,Deck Boat                                 3
# Classic,Fishing Boat                              1
# Classic,Fishing Boat,Working Boat                 1
# Classic,Flybridge                                 8
# Classic,Hardtop,Motor Yacht                       1
# Classic,House Boat,Motor Yacht                    3
# Classic,House Boat,Passenger boat                 1
# Classic,Launch                                    4
# Classic,Mega Yacht                                1
# Classic,Motor Yacht                              26
# Classic,Motor Yacht,Passenger boat                1
# Classic,Motor Yacht,Sport Boat                    1
# Classic,Motor Yacht,Water ski                     1
# Classic,Motorsailer                               1
# Classic,Pontoon Boat                              4
# Classic,Pontoon Boat,Trawler                      1
# Classic,Runabout                                 59
# Classic,Runabout,Sport Boat                       3
# Classic,Runabout,Trawler                          1
# Classic,Sport Boat                               12
# Classic,Sport Boat,Trawler                        1
# Classic,Sport Boat,Water ski                      4
# Classic,Trawler                                   5
# Classic,Working Boat                              1
# Deck Boat                                       283
# Deck Boat,Pilothouse,Sport Boat                   1
# Deck Boat,Water ski                               1
# Fishing Boat                                    173
# Fishing Boat,Flybridge,Trawler                    1
# Fishing Boat,Hardtop,Pilothouse                   1
# Fishing Boat,Launch,Motor Yacht                   1
# Fishing Boat,Passenger boat,Sport Boat            1
# Fishing Boat,Pilothouse                           1
# Fishing Boat,Sport Boat                           1
# Flybridge                                      1194
# Flybridge,Hardtop,Motor Yacht                     1
# Flybridge,Motor Yacht                             7
# Flybridge,Pilothouse                              1
# Hardtop                                         507
# Hardtop,Mega Yacht,Motor Yacht                    1
# Hardtop,Motor Yacht                               3
# Hardtop,Motor Yacht,Sport Boat                    1
# Hardtop,Sport Boat                                1
# House Boat                                      145
# House Boat,Motor Yacht                            1
# House Boat,Motor Yacht,Trawler                    1
# House Boat,Sport Boat,Trawler                     1
# Ketch                                             1
# Launch                                           55
# Mega Yacht                                      108
# Motor Yacht                                    2720
# Motor Yacht,Sport Boat                            9
# Motor Yacht,Sport Boat,Trawler                    1
# Motor Yacht,Sport Boat,Water ski                  1
# Motor Yacht,Trawler                               4
# Motor Yacht,Wakeboard/Wakesurf                    1
# Motorsailer                                       3
# Offshore Boat                                    54
# Offshore Boat,Pilothouse                          1
# Offshore Boat,Sport Boat                          2
# Passenger boat                                   33
# Passenger boat,Runabout,Sport Boat                1
# Passenger boat,Working Boat                       2
# Pilothouse                                      613
# Pilothouse,Sport Boat                             1
# Pontoon Boat                                     91
# RIB                                               1
# Runabout                                         73
# Runabout,Sport Boat                               2
# Runabout,Sport Boat,Water ski                     3
# Sport Boat                                     1407
# Sport Boat,Wakeboard/Wakesurf                     4
# Sport Boat,Wakeboard/Wakesurf,Water ski           3
# Sport Boat,Water ski                              2
# Sport Boat,Working Boat                           1
# Trawler                                         679
# Wakeboard/Wakesurf                               58
# Wakeboard/Wakesurf,Water ski                      2
# Water ski                                        10
# Working Boat                                     44
# dtype: int64

# %%
t = df['Manufacturer'].fillna('None').unique()
sorted(t)
# Out:
# ['2 emme marine power boats',
#  '3B Craft power boats',
#  'A. Mostes power boats',
#  'AB Yachts power boats',
#  'ACM Dufour power boats',
#  'AGA-Marine power boats',
#  'AICON Yachts power boats',
#  'AL Custom power boats',
#  'AM Yacht power boats',
#  'AMS Marine Yachten power boats',
#  'AMT power boats',
#  'ARS Mare power boats',
#  'AS Marine power boats',
#  'ATOMIX power boats',
#  'AW Yachts power boats',
#  'AW power boats',
#  'AXOPAR power boats',
#  'AYROS power boats',
#  'Abacus power boats',
#  'Abati Yachts power boats',
#  'Abeking & Rasmussen power boats',
#  'Absolute power boats',
#  'Acquaviva (IT) power boats',
#  'Acroplast power boats',
#  'Adagio Yachts power boats',
#  'Adec power boats',
#  'Adex Nautica power boats',
#  'Adler power boats',
#  'Admiral power boats',
#  'Adventure power boats',
#  'Aegean Yachts power boats',
#  'Agder power boats',
#  'Aicon power boats',
#  'Airon Marine power boats',
#  'Akerboom power boats',
#  'Ala Blu power boats',
#  'Alalunga power boats',
#  'Albatro power boats',
#  'Albemarle power boats',
#  'Albin power boats',
#  'Alen Yacht power boats',
#  'Alfamarine power boats',
#  'Alfastreet Marine power boats',
#  'Allegra power boats',
#  'Allround power boats',
#  'Alpa power boats',
#  'Altair power boats',
#  'Altena power boats',
#  'AluForce power boats',
#  'AluVenture power boats',
#  'Aluminiumjon power boats',
#  'Amberg power boats',
#  'Amel power boats',
#  'Amer power boats',
#  'Amerglass power boats',
#  'American Marine power boats',
#  'Ancora power boats',
#  'Antaris power boats',
#  'Anytec Boats power boats',
#  'Anytec power boats',
#  'Apreamare power boats',
#  'Aquabat power boats',
#  'Aquador power boats',
#  'Aqualum power boats',
#  'Aquanaut power boats',
#  'Aquarius power boats',
#  'Aquastar power boats',
#  'Aquaviva power boats',
#  'Arcoa power boats',
#  'Argo power boats',
#  'Arkos power boats',
#  'Armee Suisse power boats',
#  'Arp-Werft  power boats',
#  'Arvor power boats',
#  'Astinor power boats',
#  'Astondoa power boats',
#  'Astor power boats',
#  'Atlanta power boats',
#  'Atlantic Marine power boats',
#  'Atlantic Motor Yachts power boats',
#  'Atlantis power boats',
#  'Austin Parker power boats',
#  'Axis power boats',
#  'Ayros power boats',
#  'Azimut power boats',
#  'Azzurro power boats',
#  'B2 Marine power boats',
#  'BLUEGAME power boats',
#  'BLULINE (IT) power boats',
#  'BM Nautica SRL power boats',
#  'BMA power boats',
#  'BSC power boats',
#  'BWA power boats',
#  'Babro power boats',
#  'Back Cove power boats',
#  'Baess power boats',
#  'Baglietto power boats',
#  'Baha power boats',
#  'Baia power boats',
#  'Baikal power boats',
#  'Baja power boats',
#  'Balt Yacht power boats',
#  'Baltic power boats',
#  'Bandido Yachts power boats',
#  'Barkas power boats',
#  'Barro power boats',
#  'Bavaria power boats',
#  'Bayliner power boats',
#  'Bazzerla power boats',
#  'Beachcraft power boats',
#  'Beekmann power boats',
#  'Bege power boats',
#  'Bella power boats',
#  'Bellcraft power boats',
#  'Belliure power boats',
#  'Benetti power boats',
#  'Bering Yachts power boats',
#  'Bertram Yacht power boats',
#  'Bertram power boats',
#  'Best power boats',
#  'Biam power boats',
#  'Bienchen  power boats',
#  'Bimax power boats',
#  'Biot power boats',
#  'Birchwood power boats',
#  'Blackfin power boats',
#  'Blauwe Hand power boats',
#  'Blohm + Voss power boats',
#  'Blom power boats',
#  'Blu Martin power boats',
#  'Blue Navy power boats',
#  'Blue Ocean power boats',
#  'Blue Sailors power boats',
#  'BlueCraft power boats',
#  'Bluewater Yachts power boats',
#  'Bluline power boats',
#  'Blumar power boats',
#  'Boatbuilding Academy Dorset power boats',
#  'Boesch power boats',
#  'Bombard power boats',
#  'Bombardier power boats',
#  'Bond Yachts power boats',
#  'Bootbau Frei power boats',
#  'Boston Whaler power boats',
#  'Brabus power boats',
#  'Brandsma power boats',
#  'Brig power boats',
#  'Brizo Yachts power boats',
#  'Broom power boats',
#  'Brunnert-Grimm power boats',
#  'Bruno Abbate power boats',
#  'Bryant Boats power boats',
#  'Bucher power boats',
#  'Buetzfleth power boats',
#  'Bugari power boats',
#  'Burger power boats',
#  'Buster power boats',
#  'BÃ©nÃ©teau power boats',
#  'C.N. Tigullio power boats',
#  'CAD Marine power boats',
#  'Cabo power boats',
#  'Calafuria power boats',
#  'Calcagno power boats',
#  'Campion power boats',
#  'Camuffo power boats',
#  'Canados power boats',
#  'Cantiere delle Marche power boats',
#  'Cantieri Estensi power boats',
#  'Cantieri Nautici Dalla Pieta power boats',
#  'Cantieri Nautici Ferrario power boats',
#  'Cantieri Nautici Solcio power boats',
#  'Cantieri Navali Arno power boats',
#  'Cantieri Navali di Livorno power boats',
#  'Cantieri Schiavone power boats',
#  'Cantieri di Pisa power boats',
#  'Cantieri di Sarnico power boats',
#  'Cap Ferret power boats',
#  'Capelli power boats',
#  'Caravelle power boats',
#  'Carnevali power boats',
#  'Carolina Classic power boats',
#  'Carver power boats',
#  'Cascaruda power boats',
#  'Catarsi power boats',
#  'Catfish power boats',
#  'Cayman power boats',
#  'Celebrity power boats',
#  'Center Craft power boats',
#  'Centurion power boats',
#  'Century power boats',
#  'Chaparral power boats',
#  'Checkmate power boats',
#  'Chris Craft power boats',
#  'Chrysler power boats',
#  'Chung Hwa power boats',
#  'Cigala & Bertinetti power boats',
#  'Cigarette power boats',
#  'Cipax AS power boats',
#  'Clear power boats',
#  'Coaster power boats',
#  'Cobalt power boats',
#  'Cobra Yachts power boats',
#  'Cobrey power boats',
#  'Colombo power boats',
#  'Colvic power boats',
#  'Comar power boats',
#  'Comitti power boats',
#  'Compromis power boats',
#  'Conam power boats',
#  'Concordia power boats',
#  'Condor Yachting power boats',
#  'Cormate power boats',
#  'Coronet power boats',
#  'Correct Craft power boats',
#  'Corsiva power boats',
#  'Corvette Cruisers power boats',
#  'Costruzioni Navali Srl power boats',
#  'Couach power boats',
#  'Coverline power boats',
#  'Cox Marine power boats',
#  'Cramar power boats',
#  'Cranchi power boats',
#  'Crescent power boats',
#  'Crestliner power boats',
#  'Crownline power boats',
#  'Cruisers Yachts power boats',
#  'Curvelle power boats',
#  'Cytra power boats',
#  'D-Boat power boats',
#  'Dacapo power boats',
#  'Dalla Pieta power boats',
#  'Damor power boats',
#  'DarekCo power boats',
#  'Dawncraft power boats',
#  'De Antonio Yachts power boats',
#  'De Boarnstream power boats',
#  'De Groot power boats',
#  'De Vries power boats',
#  'De Wiel power boats',
#  'Dellapasqua power boats',
#  'Delphia power boats',
#  'Delta Powerboats power boats',
#  'Di Donna power boats',
#  'Diano power boats',
#  'Doerak Sneek power boats',
#  'Doggersbank power boats',
#  'Dominator power boats',
#  'Donzi power boats',
#  'Doqueve power boats',
#  'Doral power boats',
#  'Draco power boats',
#  'Drago Boats power boats',
#  'Drettmann power boats',
#  'Dufour power boats',
#  'Dynasty power boats',
#  'ERC power boats',
#  'EVO power boats',
#  'Ebbtide power boats',
#  'Ecofiber power boats',
#  'Ecoline power boats',
#  'Edership power boats',
#  'EdgeWater power boats',
#  'Egemar power boats',
#  'Egon Bredgaard power boats',
#  'Elan power boats',
#  'Elegance power boats',
#  'Elling power boats',
#  'Enterprise Marine power boats',
#  'Envision power boats',
#  'Eolo power boats',
#  'Erman Yachting power boats',
#  'Ernst Riss  power boats',
#  'Escape Sloepen power boats',
#  'Eurobanker power boats',
#  'Eurocrown power boats',
#  'Europe Marine power boats',
#  'Euroship power boats',
#  'Explorer power boats',
#  'FFW Sealver power boats',
#  'Faeton power boats',
#  'Fairline power boats',
#  'Falcon Yachts power boats',
#  'Fartes power boats',
#  'Faul power boats',
#  'Feltz power boats',
#  'Ferretti power boats',
#  'Fiart Mare power boats',
#  'Fiberline power boats',
#  'Fibramar power boats',
#  'Fidego power boats',
#  'Filippetti power boats',
#  'Fincantieri Yachts power boats',
#  'Finnlineboats power boats',
#  'Finnmaster power boats',
#  'Fipa Italiana power boats',
#  'Fjord Plast power boats',
#  'Fjord power boats',
#  'Fletcher power boats',
#  'Flevo power boats',
#  'Flipper power boats',
#  'Flying Shark power boats',
#  'Forbina power boats',
#  'Formula Cruisers power boats',
#  'Formula power boats',
#  'Fountain power boats',
#  'Fountaine Pajot power boats',
#  'Four Winns power boats',
#  'Franchini power boats',
#  'Fratelli Aprea power boats',
#  'Frauscher power boats',
#  'Freedom power boats',
#  'Funcraft power boats',
#  'Futuro power boats',
#  'FÃ¼llemann power boats',
#  'GS Nautica power boats',
#  'Gagliotta power boats',
#  'Galaxy power boats',
#  'Galeon power boats',
#  'Galia power boats',
#  'Gallart power boats',
#  'Ganz Boats power boats',
#  'Garin power boats',
#  'Gavazzi Luciano power boats',
#  'Gianetti power boats',
#  'Gibert Marine power boats',
#  'Gillissen power boats',
#  'GioMare power boats',
#  'Giorgi power boats',
#  'Giudecca power boats',
#  'Glacer power boats',
#  'Glastron power boats',
#  'Gobbi power boats',
#  'Gouwerok power boats',
#  'Grady White Boats power boats',
#  'Grand Banks power boats',
#  'Grandezza power boats',
#  'Graso power boats',
#  'Greenline power boats',
#  'Grginic power boats',
#  'Gropp power boats',
#  'Gruno power boats',
#  'Gulf Craft power boats',
#  'Guy Couach power boats',
#  'HI-Star power boats',
#  'HT Houseboats power boats',
#  'Haber power boats',
#  'Hagenah power boats',
#  'Haines Marine power boats',
#  'Haines power boats',
#  'Hans A. Deerberg power boats',
#  'Hanto power boats',
#  'Hardy Marine power boats',
#  'Harris FloteBote power boats',
#  'Hasler power boats',
#  'Hatecke power boats',
#  'Hatteras power boats',
#  'Heesen Yachts power boats',
#  'Heinrich power boats',
#  'Hellingskip power boats',
#  'Hellwig power boats',
#  'Helstede power boats',
#  'Hemiksem power boats',
#  'Hensa  power boats',
#  'HervÃ© power boats',
#  'Heyday power boats',
#  'Hille power boats',
#  'Hilter power boats',
#  'Hiltergerke power boats',
#  'Hitzler-Werft Regensburg power boats',
#  'HoWa power boats',
#  'Hock power boats',
#  'Hoekstra power boats',
#  'Holland Boat power boats',
#  'Holland StahlverdrÃ¤nger power boats',
#  'Hollandia power boats',
#  'Hooveld power boats',
#  'Horizon Yacht power boats',
#  'Hoya power boats',
#  'Huber power boats',
#  'Hunter power boats',
#  'Hunton power boats',
#  'Hustler power boats',
#  'IMP Boats power boats',
#  'IRON power boats',
#  'ISA Yachts power boats',
#  'Ibis power boats',
#  'Ibiza Boats power boats',
#  'Idea Marine power boats',
#  'Ijlstervlet power boats',
#  'Ilver power boats',
#  'Innovazione&Progetti power boats',
#  'Innovazioni e Progetti power boats',
#  'Integrity power boats',
#  'Inter power boats',
#  'Interboat DE power boats',
#  'Intermare power boats',
#  'Interster power boats',
#  'Intrepid power boats',
#  'Invader power boats',
#  'Invictus power boats',
#  'Island Gypsy power boats',
#  'Italcraft power boats',
#  'Italmar power boats',
#  'Italmarine power boats',
#  'Italversil power boats',
#  'Itama power boats',
#  'J2J Service power boats',
#  'Jacabo power boats',
#  'Jaguar power boats',
#  'Jan Van Gent power boats',
#  'Janmor power boats',
#  'Jans power boats',
#  'Javazzo power boats',
#  'Jeanneau power boats',
#  'Jetten power boats',
#  'Joda power boats',
#  'Johnson Yachts power boats',
#  'Johnson power boats',
#  'Jongert power boats',
#  'Jouandoudet power boats',
#  'KOK power boats',
#  'KaasbÃ¸ll power boats',
#  'Kaiser Bootsmanufaktur power boats',
#  'Kammin power boats',
#  'Kapiteinssloep power boats',
#  'Karel power boats',
#  'Karnic power boats',
#  'Katwijker power boats',
#  'Kelt power boats',
#  'Kempala (NL) power boats',
#  'Kempers power boats',
#  'Kiel Classic power boats',
#  'Kimple power boats',
#  'Kirie power boats',
#  'Klase A power boats',
#  'Knierim Yachtbau power boats',
#  'Koopmans power boats',
#  'Kramer power boats',
#  'Kraps power boats',
#  'Kronborg Marine power boats',
#  'La Mare power boats',
#  'Lagoon power boats',
#  'Lambro power boats',
#  'Lamor power boats',
#  'Larson power boats',
#  'Lavagna power boats',
#  'Leidi power boats',
#  'Lema power boats',
#  'Lengers power boats',
#  'Leopard power boats',
#  'Lex Boats power boats',
#  'Liberty power boats',
#  'Linden power boats',
#  'Linder power boats',
#  'Linex power boats',
#  'Linssen power boats',
#  'Loon power boats',
#  'Luhrs power boats',
#  'Lund Boats power boats',
#  'Lunde power boats',
#  'LÃ¼rssen Yachts power boats',
#  'LÃ¼tje power boats',
#  'MAS power boats',
#  'MBK power boats',
#  'MCY power boats',
#  'MMS power boats',
#  'MP Watersport power boats',
#  'Magic Yachts power boats',
#  'Magnum power boats',
#  'Mainship power boats',
#  'Maiora power boats',
#  'Majesty Yachts power boats',
#  'Majoni power boats',
#  'Makma power boats',
#  'Mako Boats power boats',
#  'Malibu power boats',
#  'Mangusta power boats',
#  'ManÃ² power boats',
#  'Marco Yachts power boats',
#  'Marex power boats',
#  'Marhen power boats',
#  'Mariah power boats',
#  'Marian power boats',
#  'Marieholm power boats',
#  'Maril power boats',
#  'Marina Brodersby power boats',
#  'Marine Offshore power boats',
#  'Marine Pro power boats',
#  'Marine Projects power boats',
#  'Marine Yachting power boats',
#  'Marine power boats',
#  'Marinello power boats',
#  'Marino CN power boats',
#  'Marino Costruzioni Nautiche power boats',
#  'Marino power boats',
#  'Marquis power boats',
#  'Martin power boats',
#  'Master power boats',
#  'MasterCraft power boats',
#  'Maxi Dolphin power boats',
#  'Maxima power boats',
#  'Maxum power boats',
#  'Mazury power boats',
#  'Meier power boats',
#  'Menorquin power boats',
#  'Meridian Yachts power boats',
#  'Mery Nautic power boats',
#  'Milan  power boats',
#  'Mingolla power boats',
#  'Minor power boats',
#  'Mira power boats',
#  'Mirage power boats',
#  'Mirakul power boats',
#  'Mochi Craft power boats',
#  'Momenta power boats',
#  'Monachus power boats',
#  'Mondo marine power boats',
#  'Monte Carlo power boats',
#  'Monte Fino power boats',
#  'Monterey power boats',
#  'Moomba power boats',
#  'Moonday power boats',
#  'Moonen power boats',
#  'Moonfleet power boats',
#  'Moonraker power boats',
#  'Morningstar power boats',
#  'Moschini power boats',
#  'Motiva power boats',
#  'Motocraft power boats',
#  'Motomar power boats',
#  'Myabca power boats',
#  'MÃ¤ndli power boats',
#  'NUVA Yachts power boats',
#  'Nadirmarine power boats',
#  'Nasbo power boats',
#  'Nautica Esposito power boats',
#  'Nautica power boats',
#  'Nautilus power boats',
#  'Nautique power boats',
#  'Navalia power boats',
#  'Navalplastica power boats',
#  'Need Yacht power boats',
#  'Neptunus Yachts power boats',
#  'Neptunus power boats',
#  'Nicols power boats',
#  'Nidelv power boats',
#  'Nimbus power boats',
#  'Nireus power boats',
#  'None',
#  'Nor Star power boats',
#  'Nor-Dan power boats',
#  'Nord Star power boats',
#  'Nord West power boats',
#  'Nordic power boats',
#  'Nordkapp power boats',
#  'Nordmanns power boats',
#  'Nordmaster power boats',
#  'Nordson power boats',
#  'NorthMaster power boats',
#  'Northern Marine power boats',
#  'Northshore Yachts power boats',
#  'Novurania power boats',
#  'Numarine power boats',
#  'Numo power boats',
#  'Nuova Jolly power boats',
#  'Nussbaumer power boats',
#  'Ocea power boats',
#  'Ocean Alexander power boats',
#  'Ocean Bay power boats',
#  'Ocean Master (US) power boats',
#  'Ocean Yachts power boats',
#  'Ockelbo power boats',
#  'Ocqueteau power boats',
#  'Off-Course power boats',
#  'Olympic power boats',
#  'Oost power boats',
#  'Orca power boats',
#  'Orkney power boats',
#  'Orskov Skibsvaerft power boats',
#  'Osprey power boats',
#  'Ott Werft power boats',
#  'Overblue power boats',
#  'Overmarine power boats',
#  'Oyster power boats',
#  'PR Marine power boats',
#  'Pacific Craft power boats',
#  'Pacific power boats',
#  'Palmer Johnson power boats',
#  'Pantera power boats',
#  'Paragon power boats',
#  'Parente power boats',
#  'Parker power boats',
#  'Pavati power boats',
#  'Pearl power boats',
#  'Pearlsea Yachts power boats',
#  'Pedrazzini power boats',
#  'Pedro power boats',
#  'Pegazus power boats',
#  'Pegiva power boats',
#  'Performance power boats',
#  'Perini Navi Spa power boats',
#  'Permare power boats',
#  'Pershing power boats',
#  'Pfeil power boats',
#  'Piantoni (IT) power boats',
#  'Piantoni power boats',
#  'Piculjan Marine power boats',
#  'Pikmeerkruiser power boats',
#  'Pioner power boats',
#  'Pirelli power boats',
#  'Platinum power boats',
#  'Poca power boats',
#  'Polar Boats power boats',
#  'Polar power boats',
#  'Polaris power boats',
#  'Poldijk Jachtbouw B.V. power boats',
#  'Pollard power boats',
#  'Pollini power boats',
#  'Portofino Marine power boats',
#  'Posillipo power boats',
#  'Premier power boats',
#  'Premiere Yacht power boats',
#  'President power boats',
#  'Prestige Yachts power boats',
#  'Primatist power boats',
#  'Primeur power boats',
#  'Princess power boats',
#  'Prins van Oranje power boats',
#  'Prinz power boats',
#  'Privateer power boats',
#  'Pro-Line power boats',
#  'Proficiat power boats',
#  'Pursuit power boats',
#  'Q-Yachts power boats',
#  'QErre power boats',
#  'Queens Yachts power boats',
#  'Quicksilver (Brunswick Marine) power boats',
#  'Quicksilver Inflatables power boats',
#  'Quicksilver power boats',
#  'Raffaelli power boats',
#  'Rampage power boats',
#  'Rancraft power boats',
#  'Rand Boats power boats',
#  'Ranger power boats',
#  'Ranieri International power boats',
#  'Ranieri power boats',
#  'Rapsody power boats',
#  'Rayglass power boats',
#  'ReLine power boats',
#  'Recla power boats',
#  'Regal power boats',
#  'Reinell power boats',
#  'Remus power boats',
#  'Renken power boats',
#  'Rhea power boats',
#  'Richard Dunston power boats',
#  'Rigiflex power boats',
#  'Rijnkruiser power boats',
#  'Rijo Kruiser power boats',
#  'Rinker power boats',
#  'Rio Iberica power boats',
#  'Rio power boats',
#  'Riva Bertram power boats',
#  'Riva power boats',
#  'Rivers and Tides power boats',
#  'Riviera power boats',
#  'Rizzardi power boats',
#  'Robalo power boats',
#  'Rodman power boats',
#  'Rodriguez Group (Italyachts) power boats',
#  'Rohn power boats',
#  'Romar power boats',
#  'Rose Island power boats',
#  'Royal Denship power boats',
#  'SACS power boats',
#  'SAS-Vektor power boats',
#  'SAY power boats',
#  'SBM power boats',
#  'ST power boats',
#  'Sabre power boats',
#  'Safter Marine power boats',
#  'Saga power boats',
#  'Sagemar power boats',
#  'Salmeri Boote power boats',
#  'Salpa power boats',
#  'San Remo power boats',
#  'Sanlorenzo power boats',
#  'Saphire power boats',
#  'Sarins power boats',
#  'Sarnico power boats',
#  'Sasga Yachts power boats',
#  'Saura power boats',
#  'Saver power boats',
#  'Saxdor power boats',
#  'Scand power boats',
#  'Scandinavia power boats',
#  'Scanner power boats',
#  'Scar power boats',
#  'Scarab power boats',
#  'Scarani power boats',
#  'Schachner power boats',
#  'Schaefer power boats',
#  'Schlosswerft power boats',
#  'Schneiter power boats',
#  'Schottel power boats',
#  'Schwarz power boats',
#  'Schweizer Bateaux power boats',
#  'Schweizer power boats',
#  'Sciallino power boats',
#  'Scout Boats power boats',
#  'Sea Pro power boats',
#  'Sea Ray power boats',
#  'Sea Sprite power boats',
#  'Sea-Doo power boats',
#  'Seaco power boats',
#  'Seacode power boats',
#  'Seagull power boats',
#  'Sealine power boats',
#  'Sealver power boats',
#  'Searider power boats',
#  'Seaswirl power boats',
#  'Seaway power boats',
#  'Seebold power boats',
#  'Selco power boats',
#  'Selection Boats power boats',
#  'Selene power boats',
#  'Selje power boats',
#  'Selva power boats',
#  'Sensation power boats',
#  'Ses Yachts power boats',
#  'Sessa power boats',
#  'Shiren power boats',
#  'Siemer power boats',
#  'Sigrist power boats',
#  'Silver power boats',
#  'Silverline power boats',
#  'Skagen power boats',
#  'Skagerrak power boats',
#  'Skarpnes power boats',
#  'Skibsplast power boats',
#  'Skilso power boats',
#  'SkilsÃ¶ power boats',
#  'Slepsk power boats',
#  'Smartboat power boats',
#  'Smartliner power boats',
#  'Smelne power boats',
#  'Solare power boats',
#  'Solcio power boats',
#  'Sonic power boats',
#  'Sossego power boats',
#  'Spertini power boats',
#  'Sport Craft power boats',
#  'Staempfli power boats',
#  'Stalder power boats',
#  'Stama power boats',
#  'Starcraft power boats',
#  'Starfisher power boats',
#  'Starweld power boats',
#  'Statement Marine power boats',
#  'Steilsteven power boats',
#  'Steiner power boats',
#  'Stickl power boats',
#  'Stilecatalini power boats',
#  'Sting power boats',
#  'Stingray power boats',
#  'Storebro power boats',
#  'Stormer power boats',
#  'Striker power boats',
#  'Succes power boats',
#  'Sunbird power boats',
#  'Suncamper power boats',
#  'Sunchaser power boats',
#  'Suncoast power boats',
#  'Sunreef power boats',
#  'Sunseeker power boats',
#  'Super Kaagkruiser power boats',
#  'Super Lauwersmeer power boats',
#  'Super van Craft power boats',
#  'Supra power boats',
#  'Suzuki power boats',
#  'Swiss Craft power boats',
#  'Swordsman power boats',
#  'Sylvan Marine power boats',
#  'Symbol Yachts power boats',
#  'Ta Yang power boats',
#  'Tahoe power boats',
#  'Targa power boats',
#  'Tarquin power boats',
#  'Tauscheck power boats',
#  'Techno Yachts power boats',
#  'Technohull power boats',
#  'Technus power boats',
#  'Tecnomar power boats',
#  'Tecnomarine power boats',
#  'Tecnorib power boats',
#  'Tegernseer Bootsbau power boats',
#  'Teltow Werft power boats',
#  'Ten Broeke power boats',
#  'Terhi power boats',
#  'Terra Nauta power boats',
#  'The Captains power boats',
#  'Thermo Yacht power boats',
#  'Thoma power boats',
#  'Thompson power boats',
#  'Thunderbird power boats',
#  'Tiara power boats',
#  'TigÃ© power boats',
#  'Tinn-Silver power boats',
#  'Titanium power boats',
#  'Tjeukemer power boats',
#  'Tony Giugliano power boats',
#  'Topaz power boats',
#  'Tornado power boats',
#  'Tracker Marine power boats',
#  'Trader Motor Yachts power boats',
#  'Trawler power boats',
#  'Treffer power boats',
#  'Tresfjord power boats',
#  'Trimarchi  power boats',
#  'Tristan power boats',
#  'Triton power boats',
#  'Trojan power boats',
#  'Trophy power boats',
#  'Tryvia power boats',
#  'Tuccoli power boats',
#  'Tullio Abbate power boats',
#  'UMS-Boat power boats',
#  'Ultramar power boats',
#  'Unica Yacht power boats',
#  'Uniesse power boats',
#  'Uttern power boats',
#  'V2 Boats  power boats',
#  'VBoats power boats',
#  'VEB power boats',
#  'VICEM power boats',
#  'VTS Boats power boats',
#  'VZ Cantiere Nautico power boats',
#  'Vacance power boats',
#  'Valiant power boats',
#  'Valk power boats',
#  'Valkkruiser power boats',
#  'VanDutch power boats',
#  'Vedette power boats',
#  'Veha power boats',
#  'Ventus power boats',
#  'Verhoeven power boats',
#  'Vertens power boats',
#  'Verus power boats',
#  'Victoria power boats',
#  'Viking (GB) power boats',
#  'Viking Marin power boats',
#  'Viking power boats',
#  'Viknes power boats',
#  'Viko Yachts power boats',
#  'Viko power boats',
#  'Viksund power boats',
#  'Viper power boats',
#  'Vismara power boats',
#  'Vitech power boats',
#  'Vizianello power boats',
#  'Vizion power boats',
#  'Volvo power boats',
#  'Voyager power boats',
#  'Vri-Jon power boats',
#  'Vrijbuiter power boats',
#  'Waddenkruiser power boats',
#  'Wajer power boats',
#  'Wake power boats',
#  'Walser power boats',
#  'Waltjen power boats',
#  'Waterdream power boats',
#  'Waterland power boats',
#  'Webbcraft power boats',
#  'WeiBo power boats',
#  'Weidling power boats',
#  'Wellcraft power boats',
#  'Werner  power boats',
#  'West Bay power boats',
#  'Westwind power boats',
#  'Whaly power boats',
#  'White Shark power boats',
#  'Wicabo power boats',
#  'Wider power boats',
#  'Wiking power boats',
#  'Williams power boats',
#  'Wim van der Valk power boats',
#  'Windy Oceancraft power boats',
#  'Windy power boats',
#  'Winga power boats',
#  'Witti power boats',
#  'XL Marine power boats',
#  'XO Boats power boats',
#  'Yacht Service SP. z o.o.  power boats',
#  'Yachting France power boats',
#  'Yachtwerft Berlin power boats',
#  'Yamaha power boats',
#  'Yamarin power boats',
#  'Yaretti power boats',
#  'Z-Yacht power boats',
#  'ZAR Formenti power boats',
#  'Zeeland Jachtbouw power boats',
#  'Zeta Group power boats',
#  'Zetacraft power boats',
#  'Zijlmans power boats',
#  'Zodiac power boats',
#  'Zuiderzee power boats',
#  'de Ruiter power boats',
#  'van Wijk power boats',
#  'van de Werf power boats',
#  'van der Heijden power boats',
#  'Ã\x96chsner power boats']

# %%
df['Manufacturer'] = df['Manufacturer'].fillna('None Specified')
df['Manufacturer'] = df['Manufacturer'].str.replace(' power boats', '')
mfrs_misspelled = df[df.Manufacturer.str.contains(r'[^0-9a-zA-Z -.]')].Manufacturer.unique()

# %%
df['Manufacturer'] = [fix_text(i) for i in df['Manufacturer']]
t = df['Manufacturer'].unique()
sorted(t)
# Out:
# ['2 emme marine',
#  '3B Craft',
#  'A. Mostes',
#  'AB Yachts',
#  'ACM Dufour',
#  'AGA-Marine',
#  'AICON Yachts',
#  'AL Custom',
#  'AM Yacht',
#  'AMS Marine Yachten',
#  'AMT',
#  'ARS Mare',
#  'AS Marine',
#  'ATOMIX',
#  'AW',
#  'AW Yachts',
#  'AXOPAR',
#  'AYROS',
#  'Abacus',
#  'Abati Yachts',
#  'Abeking & Rasmussen',
#  'Absolute',
#  'Acquaviva (IT)',
#  'Acroplast',
#  'Adagio Yachts',
#  'Adec',
#  'Adex Nautica',
#  'Adler',
#  'Admiral',
#  'Adventure',
#  'Aegean Yachts',
#  'Agder',
#  'Aicon',
#  'Airon Marine',
#  'Akerboom',
#  'Ala Blu',
#  'Alalunga',
#  'Albatro',
#  'Albemarle',
#  'Albin',
#  'Alen Yacht',
#  'Alfamarine',
#  'Alfastreet Marine',
#  'Allegra',
#  'Allround',
#  'Alpa',
#  'Altair',
#  'Altena',
#  'AluForce',
#  'AluVenture',
#  'Aluminiumjon',
#  'Amberg',
#  'Amel',
#  'Amer',
#  'Amerglass',
#  'American Marine',
#  'Ancora',
#  'Antaris',
#  'Anytec',
#  'Anytec Boats',
#  'Apreamare',
#  'Aquabat',
#  'Aquador',
#  'Aqualum',
#  'Aquanaut',
#  'Aquarius',
#  'Aquastar',
#  'Aquaviva',
#  'Arcoa',
#  'Argo',
#  'Arkos',
#  'Armee Suisse',
#  'Arp-Werft ',
#  'Arvor',
#  'Astinor',
#  'Astondoa',
#  'Astor',
#  'Atlanta',
#  'Atlantic Marine',
#  'Atlantic Motor Yachts',
#  'Atlantis',
#  'Austin Parker',
#  'Axis',
#  'Ayros',
#  'Azimut',
#  'Azzurro',
#  'B2 Marine',
#  'BLUEGAME',
#  'BLULINE (IT)',
#  'BM Nautica SRL',
#  'BMA',
#  'BSC',
#  'BWA',
#  'Babro',
#  'Back Cove',
#  'Baess',
#  'Baglietto',
#  'Baha',
#  'Baia',
#  'Baikal',
#  'Baja',
#  'Balt Yacht',
#  'Baltic',
#  'Bandido Yachts',
#  'Barkas',
#  'Barro',
#  'Bavaria',
#  'Bayliner',
#  'Bazzerla',
#  'Beachcraft',
#  'Beekmann',
#  'Bege',
#  'Bella',
#  'Bellcraft',
#  'Belliure',
#  'Benetti',
#  'Bering Yachts',
#  'Bertram',
#  'Bertram Yacht',
#  'Best',
#  'Biam',
#  'Bienchen ',
#  'Bimax',
#  'Biot',
#  'Birchwood',
#  'Blackfin',
#  'Blauwe Hand',
#  'Blohm + Voss',
#  'Blom',
#  'Blu Martin',
#  'Blue Navy',
#  'Blue Ocean',
#  'Blue Sailors',
#  'BlueCraft',
#  'Bluewater Yachts',
#  'Bluline',
#  'Blumar',
#  'Boatbuilding Academy Dorset',
#  'Boesch',
#  'Bombard',
#  'Bombardier',
#  'Bond Yachts',
#  'Bootbau Frei',
#  'Boston Whaler',
#  'Brabus',
#  'Brandsma',
#  'Brig',
#  'Brizo Yachts',
#  'Broom',
#  'Brunnert-Grimm',
#  'Bruno Abbate',
#  'Bryant Boats',
#  'Bucher',
#  'Buetzfleth',
#  'Bugari',
#  'Burger',
#  'Buster',
#  'Bénéteau',
#  'C.N. Tigullio',
#  'CAD Marine',
#  'Cabo',
#  'Calafuria',
#  'Calcagno',
#  'Campion',
#  'Camuffo',
#  'Canados',
#  'Cantiere delle Marche',
#  'Cantieri Estensi',
#  'Cantieri Nautici Dalla Pieta',
#  'Cantieri Nautici Ferrario',
#  'Cantieri Nautici Solcio',
#  'Cantieri Navali Arno',
#  'Cantieri Navali di Livorno',
#  'Cantieri Schiavone',
#  'Cantieri di Pisa',
#  'Cantieri di Sarnico',
#  'Cap Ferret',
#  'Capelli',
#  'Caravelle',
#  'Carnevali',
#  'Carolina Classic',
#  'Carver',
#  'Cascaruda',
#  'Catarsi',
#  'Catfish',
#  'Cayman',
#  'Celebrity',
#  'Center Craft',
#  'Centurion',
#  'Century',
#  'Chaparral',
#  'Checkmate',
#  'Chris Craft',
#  'Chrysler',
#  'Chung Hwa',
#  'Cigala & Bertinetti',
#  'Cigarette',
#  'Cipax AS',
#  'Clear',
#  'Coaster',
#  'Cobalt',
#  'Cobra Yachts',
#  'Cobrey',
#  'Colombo',
#  'Colvic',
#  'Comar',
#  'Comitti',
#  'Compromis',
#  'Conam',
#  'Concordia',
#  'Condor Yachting',
#  'Cormate',
#  'Coronet',
#  'Correct Craft',
#  'Corsiva',
#  'Corvette Cruisers',
#  'Costruzioni Navali Srl',
#  'Couach',
#  'Coverline',
#  'Cox Marine',
#  'Cramar',
#  'Cranchi',
#  'Crescent',
#  'Crestliner',
#  'Crownline',
#  'Cruisers Yachts',
#  'Curvelle',
#  'Cytra',
#  'D-Boat',
#  'Dacapo',
#  'Dalla Pieta',
#  'Damor',
#  'DarekCo',
#  'Dawncraft',
#  'De Antonio Yachts',
#  'De Boarnstream',
#  'De Groot',
#  'De Vries',
#  'De Wiel',
#  'Dellapasqua',
#  'Delphia',
#  'Delta Powerboats',
#  'Di Donna',
#  'Diano',
#  'Doerak Sneek',
#  'Doggersbank',
#  'Dominator',
#  'Donzi',
#  'Doqueve',
#  'Doral',
#  'Draco',
#  'Drago Boats',
#  'Drettmann',
#  'Dufour',
#  'Dynasty',
#  'ERC',
#  'EVO',
#  'Ebbtide',
#  'Ecofiber',
#  'Ecoline',
#  'Edership',
#  'EdgeWater',
#  'Egemar',
#  'Egon Bredgaard',
#  'Elan',
#  'Elegance',
#  'Elling',
#  'Enterprise Marine',
#  'Envision',
#  'Eolo',
#  'Erman Yachting',
#  'Ernst Riss ',
#  'Escape Sloepen',
#  'Eurobanker',
#  'Eurocrown',
#  'Europe Marine',
#  'Euroship',
#  'Explorer',
#  'FFW Sealver',
#  'Faeton',
#  'Fairline',
#  'Falcon Yachts',
#  'Fartes',
#  'Faul',
#  'Feltz',
#  'Ferretti',
#  'Fiart Mare',
#  'Fiberline',
#  'Fibramar',
#  'Fidego',
#  'Filippetti',
#  'Fincantieri Yachts',
#  'Finnlineboats',
#  'Finnmaster',
#  'Fipa Italiana',
#  'Fjord',
#  'Fjord Plast',
#  'Fletcher',
#  'Flevo',
#  'Flipper',
#  'Flying Shark',
#  'Forbina',
#  'Formula',
#  'Formula Cruisers',
#  'Fountain',
#  'Fountaine Pajot',
#  'Four Winns',
#  'Franchini',
#  'Fratelli Aprea',
#  'Frauscher',
#  'Freedom',
#  'Funcraft',
#  'Futuro',
#  'Füllemann',
#  'GS Nautica',
#  'Gagliotta',
#  'Galaxy',
#  'Galeon',
#  'Galia',
#  'Gallart',
#  'Ganz Boats',
#  'Garin',
#  'Gavazzi Luciano',
#  'Gianetti',
#  'Gibert Marine',
#  'Gillissen',
#  'GioMare',
#  'Giorgi',
#  'Giudecca',
#  'Glacer',
#  'Glastron',
#  'Gobbi',
#  'Gouwerok',
#  'Grady White Boats',
#  'Grand Banks',
#  'Grandezza',
#  'Graso',
#  'Greenline',
#  'Grginic',
#  'Gropp',
#  'Gruno',
#  'Gulf Craft',
#  'Guy Couach',
#  'HI-Star',
#  'HT Houseboats',
#  'Haber',
#  'Hagenah',
#  'Haines',
#  'Haines Marine',
#  'Hans A. Deerberg',
#  'Hanto',
#  'Hardy Marine',
#  'Harris FloteBote',
#  'Hasler',
#  'Hatecke',
#  'Hatteras',
#  'Heesen Yachts',
#  'Heinrich',
#  'Hellingskip',
#  'Hellwig',
#  'Helstede',
#  'Hemiksem',
#  'Hensa ',
#  'Hervé',
#  'Heyday',
#  'Hille',
#  'Hilter',
#  'Hiltergerke',
#  'Hitzler-Werft Regensburg',
#  'HoWa',
#  'Hock',
#  'Hoekstra',
#  'Holland Boat',
#  'Holland Stahlverdränger',
#  'Hollandia',
#  'Hooveld',
#  'Horizon Yacht',
#  'Hoya',
#  'Huber',
#  'Hunter',
#  'Hunton',
#  'Hustler',
#  'IMP Boats',
#  'IRON',
#  'ISA Yachts',
#  'Ibis',
#  'Ibiza Boats',
#  'Idea Marine',
#  'Ijlstervlet',
#  'Ilver',
#  'Innovazione&Progetti',
#  'Innovazioni e Progetti',
#  'Integrity',
#  'Inter',
#  'Interboat DE',
#  'Intermare',
#  'Interster',
#  'Intrepid',
#  'Invader',
#  'Invictus',
#  'Island Gypsy',
#  'Italcraft',
#  'Italmar',
#  'Italmarine',
#  'Italversil',
#  'Itama',
#  'J2J Service',
#  'Jacabo',
#  'Jaguar',
#  'Jan Van Gent',
#  'Janmor',
#  'Jans',
#  'Javazzo',
#  'Jeanneau',
#  'Jetten',
#  'Joda',
#  'Johnson',
#  'Johnson Yachts',
#  'Jongert',
#  'Jouandoudet',
#  'KOK',
#  'Kaasbøll',
#  'Kaiser Bootsmanufaktur',
#  'Kammin',
#  'Kapiteinssloep',
#  'Karel',
#  'Karnic',
#  'Katwijker',
#  'Kelt',
#  'Kempala (NL)',
#  'Kempers',
#  'Kiel Classic',
#  'Kimple',
#  'Kirie',
#  'Klase A',
#  'Knierim Yachtbau',
#  'Koopmans',
#  'Kramer',
#  'Kraps',
#  'Kronborg Marine',
#  'La Mare',
#  'Lagoon',
#  'Lambro',
#  'Lamor',
#  'Larson',
#  'Lavagna',
#  'Leidi',
#  'Lema',
#  'Lengers',
#  'Leopard',
#  'Lex Boats',
#  'Liberty',
#  'Linden',
#  'Linder',
#  'Linex',
#  'Linssen',
#  'Loon',
#  'Luhrs',
#  'Lund Boats',
#  'Lunde',
#  'Lürssen Yachts',
#  'Lütje',
#  'MAS',
#  'MBK',
#  'MCY',
#  'MMS',
#  'MP Watersport',
#  'Magic Yachts',
#  'Magnum',
#  'Mainship',
#  'Maiora',
#  'Majesty Yachts',
#  'Majoni',
#  'Makma',
#  'Mako Boats',
#  'Malibu',
#  'Mangusta',
#  'Manò',
#  'Marco Yachts',
#  'Marex',
#  'Marhen',
#  'Mariah',
#  'Marian',
#  'Marieholm',
#  'Maril',
#  'Marina Brodersby',
#  'Marine',
#  'Marine Offshore',
#  'Marine Pro',
#  'Marine Projects',
#  'Marine Yachting',
#  'Marinello',
#  'Marino',
#  'Marino CN',
#  'Marino Costruzioni Nautiche',
#  'Marquis',
#  'Martin',
#  'Master',
#  'MasterCraft',
#  'Maxi Dolphin',
#  'Maxima',
#  'Maxum',
#  'Mazury',
#  'Meier',
#  'Menorquin',
#  'Meridian Yachts',
#  'Mery Nautic',
#  'Milan ',
#  'Mingolla',
#  'Minor',
#  'Mira',
#  'Mirage',
#  'Mirakul',
#  'Mochi Craft',
#  'Momenta',
#  'Monachus',
#  'Mondo marine',
#  'Monte Carlo',
#  'Monte Fino',
#  'Monterey',
#  'Moomba',
#  'Moonday',
#  'Moonen',
#  'Moonfleet',
#  'Moonraker',
#  'Morningstar',
#  'Moschini',
#  'Motiva',
#  'Motocraft',
#  'Motomar',
#  'Myabca',
#  'Mändli',
#  'NUVA Yachts',
#  'Nadirmarine',
#  'Nasbo',
#  'Nautica',
#  'Nautica Esposito',
#  'Nautilus',
#  'Nautique',
#  'Navalia',
#  'Navalplastica',
#  'Need Yacht',
#  'Neptunus',
#  'Neptunus Yachts',
#  'Nicols',
#  'Nidelv',
#  'Nimbus',
#  'Nireus',
#  'None Specified',
#  'Nor Star',
#  'Nor-Dan',
#  'Nord Star',
#  'Nord West',
#  'Nordic',
#  'Nordkapp',
#  'Nordmanns',
#  'Nordmaster',
#  'Nordson',
#  'NorthMaster',
#  'Northern Marine',
#  'Northshore Yachts',
#  'Novurania',
#  'Numarine',
#  'Numo',
#  'Nuova Jolly',
#  'Nussbaumer',
#  'Ocea',
#  'Ocean Alexander',
#  'Ocean Bay',
#  'Ocean Master (US)',
#  'Ocean Yachts',
#  'Ockelbo',
#  'Ocqueteau',
#  'Off-Course',
#  'Olympic',
#  'Oost',
#  'Orca',
#  'Orkney',
#  'Orskov Skibsvaerft',
#  'Osprey',
#  'Ott Werft',
#  'Overblue',
#  'Overmarine',
#  'Oyster',
#  'PR Marine',
#  'Pacific',
#  'Pacific Craft',
#  'Palmer Johnson',
#  'Pantera',
#  'Paragon',
#  'Parente',
#  'Parker',
#  'Pavati',
#  'Pearl',
#  'Pearlsea Yachts',
#  'Pedrazzini',
#  'Pedro',
#  'Pegazus',
#  'Pegiva',
#  'Performance',
#  'Perini Navi Spa',
#  'Permare',
#  'Pershing',
#  'Pfeil',
#  'Piantoni',
#  'Piantoni (IT)',
#  'Piculjan Marine',
#  'Pikmeerkruiser',
#  'Pioner',
#  'Pirelli',
#  'Platinum',
#  'Poca',
#  'Polar',
#  'Polar Boats',
#  'Polaris',
#  'Poldijk Jachtbouw B.V.',
#  'Pollard',
#  'Pollini',
#  'Portofino Marine',
#  'Posillipo',
#  'Premier',
#  'Premiere Yacht',
#  'President',
#  'Prestige Yachts',
#  'Primatist',
#  'Primeur',
#  'Princess',
#  'Prins van Oranje',
#  'Prinz',
#  'Privateer',
#  'Pro-Line',
#  'Proficiat',
#  'Pursuit',
#  'Q-Yachts',
#  'QErre',
#  'Queens Yachts',
#  'Quicksilver',
#  'Quicksilver (Brunswick Marine)',
#  'Quicksilver Inflatables',
#  'Raffaelli',
#  'Rampage',
#  'Rancraft',
#  'Rand Boats',
#  'Ranger',
#  'Ranieri',
#  'Ranieri International',
#  'Rapsody',
#  'Rayglass',
#  'ReLine',
#  'Recla',
#  'Regal',
#  'Reinell',
#  'Remus',
#  'Renken',
#  'Rhea',
#  'Richard Dunston',
#  'Rigiflex',
#  'Rijnkruiser',
#  'Rijo Kruiser',
#  'Rinker',
#  'Rio',
#  'Rio Iberica',
#  'Riva',
#  'Riva Bertram',
#  'Rivers and Tides',
#  'Riviera',
#  'Rizzardi',
#  'Robalo',
#  'Rodman',
#  'Rodriguez Group (Italyachts)',
#  'Rohn',
#  'Romar',
#  'Rose Island',
#  'Royal Denship',
#  'SACS',
#  'SAS-Vektor',
#  'SAY',
#  'SBM',
#  'ST',
#  'Sabre',
#  'Safter Marine',
#  'Saga',
#  'Sagemar',
#  'Salmeri Boote',
#  'Salpa',
#  'San Remo',
#  'Sanlorenzo',
#  'Saphire',
#  'Sarins',
#  'Sarnico',
#  'Sasga Yachts',
#  'Saura',
#  'Saver',
#  'Saxdor',
#  'Scand',
#  'Scandinavia',
#  'Scanner',
#  'Scar',
#  'Scarab',
#  'Scarani',
#  'Schachner',
#  'Schaefer',
#  'Schlosswerft',
#  'Schneiter',
#  'Schottel',
#  'Schwarz',
#  'Schweizer',
#  'Schweizer Bateaux',
#  'Sciallino',
#  'Scout Boats',
#  'Sea Pro',
#  'Sea Ray',
#  'Sea Sprite',
#  'Sea-Doo',
#  'Seaco',
#  'Seacode',
#  'Seagull',
#  'Sealine',
#  'Sealver',
#  'Searider',
#  'Seaswirl',
#  'Seaway',
#  'Seebold',
#  'Selco',
#  'Selection Boats',
#  'Selene',
#  'Selje',
#  'Selva',
#  'Sensation',
#  'Ses Yachts',
#  'Sessa',
#  'Shiren',
#  'Siemer',
#  'Sigrist',
#  'Silver',
#  'Silverline',
#  'Skagen',
#  'Skagerrak',
#  'Skarpnes',
#  'Skibsplast',
#  'Skilso',
#  'Skilsö',
#  'Slepsk',
#  'Smartboat',
#  'Smartliner',
#  'Smelne',
#  'Solare',
#  'Solcio',
#  'Sonic',
#  'Sossego',
#  'Spertini',
#  'Sport Craft',
#  'Staempfli',
#  'Stalder',
#  'Stama',
#  'Starcraft',
#  'Starfisher',
#  'Starweld',
#  'Statement Marine',
#  'Steilsteven',
#  'Steiner',
#  'Stickl',
#  'Stilecatalini',
#  'Sting',
#  'Stingray',
#  'Storebro',
#  'Stormer',
#  'Striker',
#  'Succes',
#  'Sunbird',
#  'Suncamper',
#  'Sunchaser',
#  'Suncoast',
#  'Sunreef',
#  'Sunseeker',
#  'Super Kaagkruiser',
#  'Super Lauwersmeer',
#  'Super van Craft',
#  'Supra',
#  'Suzuki',
#  'Swiss Craft',
#  'Swordsman',
#  'Sylvan Marine',
#  'Symbol Yachts',
#  'Ta Yang',
#  'Tahoe',
#  'Targa',
#  'Tarquin',
#  'Tauscheck',
#  'Techno Yachts',
#  'Technohull',
#  'Technus',
#  'Tecnomar',
#  'Tecnomarine',
#  'Tecnorib',
#  'Tegernseer Bootsbau',
#  'Teltow Werft',
#  'Ten Broeke',
#  'Terhi',
#  'Terra Nauta',
#  'The Captains',
#  'Thermo Yacht',
#  'Thoma',
#  'Thompson',
#  'Thunderbird',
#  'Tiara',
#  'Tigé',
#  'Tinn-Silver',
#  'Titanium',
#  'Tjeukemer',
#  'Tony Giugliano',
#  'Topaz',
#  'Tornado',
#  'Tracker Marine',
#  'Trader Motor Yachts',
#  'Trawler',
#  'Treffer',
#  'Tresfjord',
#  'Trimarchi ',
#  'Tristan',
#  'Triton',
#  'Trojan',
#  'Trophy',
#  'Tryvia',
#  'Tuccoli',
#  'Tullio Abbate',
#  'UMS-Boat',
#  'Ultramar',
#  'Unica Yacht',
#  'Uniesse',
#  'Uttern',
#  'V2 Boats ',
#  'VBoats',
#  'VEB',
#  'VICEM',
#  'VTS Boats',
#  'VZ Cantiere Nautico',
#  'Vacance',
#  'Valiant',
#  'Valk',
#  'Valkkruiser',
#  'VanDutch',
#  'Vedette',
#  'Veha',
#  'Ventus',
#  'Verhoeven',
#  'Vertens',
#  'Verus',
#  'Victoria',
#  'Viking',
#  'Viking (GB)',
#  'Viking Marin',
#  'Viknes',
#  'Viko',
#  'Viko Yachts',
#  'Viksund',
#  'Viper',
#  'Vismara',
#  'Vitech',
#  'Vizianello',
#  'Vizion',
#  'Volvo',
#  'Voyager',
#  'Vri-Jon',
#  'Vrijbuiter',
#  'Waddenkruiser',
#  'Wajer',
#  'Wake',
#  'Walser',
#  'Waltjen',
#  'Waterdream',
#  'Waterland',
#  'Webbcraft',
#  'WeiBo',
#  'Weidling',
#  'Wellcraft',
#  'Werner ',
#  'West Bay',
#  'Westwind',
#  'Whaly',
#  'White Shark',
#  'Wicabo',
#  'Wider',
#  'Wiking',
#  'Williams',
#  'Wim van der Valk',
#  'Windy',
#  'Windy Oceancraft',
#  'Winga',
#  'Witti',
#  'XL Marine',
#  'XO Boats',
#  'Yacht Service SP. z o.o. ',
#  'Yachting France',
#  'Yachtwerft Berlin',
#  'Yamaha',
#  'Yamarin',
#  'Yaretti',
#  'Z-Yacht',
#  'ZAR Formenti',
#  'Zeeland Jachtbouw',
#  'Zeta Group',
#  'Zetacraft',
#  'Zijlmans',
#  'Zodiac',
#  'Zuiderzee',
#  'de Ruiter',
#  'van Wijk',
#  'van de Werf',
#  'van der Heijden',
#  'Öchsner']

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.groupby('Manufacturer').size().sort_values(ascending = False))
# Out:
# Manufacturer
# None Specified                    1338
# Bénéteau                           631
# Jeanneau                           537
# Sunseeker                          383
# Princess                           241
# Sea Ray                            239
# Cranchi                            219
# Azimut                             215
# Bavaria                            185
# Fairline                           172
# Quicksilver (Brunswick Marine)     167
# Sessa                              148
# Bayliner                           142
# Sealine                            120
# Quicksilver                        118
# Prestige Yachts                    108
# Galeon                              94
# Regal                               90
# Riva                                77
# Linssen                             70
# Windy                               64
# Ferretti                            63
# Parker                              62
# Boesch                              55
# Pershing                            54
# Four Winns                          50
# Gobbi                               46
# Nimbus                              45
# Yamarin                             42
# Sanlorenzo                          41
# Rodman                              40
# Chaparral                           40
# Invictus                            39
# Astondoa                            39
# Saver                               39
# Boston Whaler                       39
# Atlantis                            39
# Viper                               37
# Crownline                           37
# Chris Craft                         35
# Pedro                               35
# Fjord                               34
# Absolute                            34
# Marinello                           34
# Rhea                                33
# Menorquin                           33
# Fiart Mare                          33
# Marex                               32
# Campion                             31
# Apreamare                           30
# Airon Marine                        29
# Glastron                            28
# Ranieri International               28
# Greenline                           27
# Drago Boats                         26
# Raffaelli                           26
# Maxum                               25
# Frauscher                           25
# MasterCraft                         25
# Cobalt                              24
# Draco                               24
# Aquador                             24
# Ocqueteau                           24
# Rinker                              24
# Innovazioni e Progetti              24
# Formula                             23
# Dellapasqua                         22
# Monterey                            22
# Faeton                              22
# Mochi Craft                         22
# Rio                                 21
# Cayman                              21
# Buster                              20
# Linder                              19
# Neptunus                            19
# AMT                                 19
# Bella                               19
# Cruisers Yachts                     19
# Majesty Yachts                      18
# Grand Banks                         18
# Larson                              17
# Manò                                17
# Smelne                              17
# Performance                         17
# Nautique                            17
# Dominator                           16
# Storebro                            16
# Eolo                                16
# Karnic                              16
# Galia                               16
# Colombo                             16
# Ilver                               16
# Terhi                               16
# Carnevali                           15
# Pioner                              15
# Aicon                               15
# Tullio Abbate                       15
# Finnmaster                          15
# Crescent                            15
# Rizzardi                            15
# Uniesse                             14
# Scand                               14
# Riviera                             14
# Nordkapp                            14
# Succes                              14
# Ganz Boats                          14
# Baia                                14
# B2 Marine                           14
# Intermare                           13
# Wellcraft                           13
# Flipper                             13
# Tiara                               13
# Hatteras                            13
# Elan                                13
# AXOPAR                              13
# Doral                               13
# Viking                              12
# Capelli                             12
# Bruno Abbate                        12
# Gruno                               12
# Conam                               12
# Piantoni (IT)                       12
# Valkkruiser                         12
# Cantieri Estensi                    12
# Integrity                           11
# Nidelv                              11
# Carver                              11
# Salpa                               11
# VBoats                              11
# Fountaine Pajot                     11
# De Boarnstream                      11
# Maiora                              11
# Bertram Yacht                       11
# Aquanaut                            11
# Kelt                                11
# Valk                                10
# Correct Craft                       10
# Sting                               10
# Allegra                             10
# XO Boats                            10
# Malibu                              10
# Altena                              10
# Pursuit                             10
# Canados                             10
# ACM Dufour                          10
# Super van Craft                     10
# Broom                               10
# Pedrazzini                           9
# Italmar                              9
# Vri-Jon                              9
# VanDutch                             9
# Posillipo                            9
# Selection Boats                      9
# MCY                                  9
# van der Heijden                      9
# Rapsody                              9
# Benetti                              9
# Proficiat                            9
# Itama                                9
# Edership                             9
# AluForce                             9
# Master                               9
# Doqueve                              8
# Tecnomar                             8
# Marine                               8
# Clear                                8
# Selene                               8
# DarekCo                              8
# Elegance                             8
# Italcraft                            8
# Tornado                              8
# Starfisher                           8
# Smartliner                           8
# Hollandia                            8
# Leopard                              8
# Stingray                             8
# Olympic                              8
# Grandezza                            8
# Bandido Yachts                       8
# Ranieri                              8
# President                            7
# Saxdor                               7
# Pirelli                              7
# Delphia                              7
# BlueCraft                            7
# Mändli                               7
# Comitti                              7
# Corsiva                              7
# Mangusta                             7
# Scarab                               7
# IRON                                 7
# Birchwood                            7
# Moonday                              7
# Orkney                               7
# Sunchaser                            7
# Tecnorib                             7
# Bertram                              7
# Dalla Pieta                          7
# Elling                               7
# Balt Yacht                           7
# Baglietto                            7
# Mingolla                             6
# Baikal                               6
# Polaris                              6
# De Antonio Yachts                    6
# Inter                                6
# Silver                               6
# Marine Projects                      6
# Sciallino                            6
# Arvor                                6
# Cantieri di Sarnico                  6
# Sensation                            6
# Zijlmans                             6
# Guy Couach                           6
# Arcoa                                6
# A. Mostes                            6
# Alfastreet Marine                    6
# Primatist                            6
# Thoma                                6
# Pro-Line                             6
# Cantieri Nautici Ferrario            6
# Seaswirl                             5
# Lema                                 5
# Atlantic Marine                      5
# Vizion                               5
# Sunreef                              5
# De Groot                             5
# Portofino Marine                     5
# Selva                                5
# AICON Yachts                         5
# Atlantic Motor Yachts                5
# Albemarle                            5
# Baja                                 5
# Pikmeerkruiser                       5
# Giorgi                               5
# Cantieri di Pisa                     5
# Gianetti                             5
# Saga                                 5
# Tuccoli                              5
# Nord Star                            5
# Yaretti                              5
# Overmarine                           5
# Cigarette                            5
# Sarnico                              5
# Pacific                              5
# Ijlstervlet                          5
# Wim van der Valk                     5
# Century                              5
# Solcio                               5
# Hilter                               5
# Moomba                               5
# AS Marine                            5
# Ocean Master (US)                    5
# Brizo Yachts                         5
# Brandsma                             5
# Brabus                               5
# Aquastar                             4
# Kaiser Bootsmanufaktur               4
# Gillissen                            4
# Huber                                4
# Rand Boats                           4
# Skibsplast                           4
# Hardy Marine                         4
# Stickl                               4
# Hock                                 4
# Fiberline                            4
# Swiss Craft                          4
# Antaris                              4
# Gagliotta                            4
# Hellwig                              4
# Filippetti                           4
# Heyday                               4
# Füllemann                            4
# Sunbird                              4
# Seaway                               4
# Motomar                              4
# Coverline                            4
# Monte Carlo                          4
# Abacus                               4
# Coronet                              4
# Cormate                              4
# Treffer                              4
# Pacific Craft                        4
# Trimarchi                            4
# Cobrey                               4
# BLUEGAME                             4
# BMA                                  4
# Ultramar                             4
# NUVA Yachts                          4
# SAS-Vektor                           4
# Centurion                            4
# Sagemar                              4
# SAY                                  4
# Nordmaster                           4
# ST                                   4
# Safter Marine                        4
# Di Donna                             4
# Belliure                             4
# Biam                                 4
# Cytra                                4
# Pfeil                                4
# EdgeWater                            4
# Damor                                4
# Maxima                               4
# Marquis                              4
# Delta Powerboats                     4
# Majoni                               4
# ReLine                               4
# Remus                                3
# Prinz                                3
# Barkas                               3
# Hille                                3
# Polar Boats                          3
# Polar                                3
# Robalo                               3
# Permare                              3
# de Ruiter                            3
# Piculjan Marine                      3
# Rio Iberica                          3
# Hiltergerke                          3
# Pegazus                              3
# Innovazione&Progetti                 3
# Starcraft                            3
# Skagerrak                            3
# Linex                                3
# Alpa                                 3
# XL Marine                            3
# Makma                                3
# Sea-Doo                              3
# Lagoon                               3
# Alfamarine                           3
# Albatro                              3
# Katwijker                            3
# Mirakul                              3
# Sarins                               3
# Jetten                               3
# Alalunga                             3
# Jacabo                               3
# Scarani                              3
# Ala Blu                              3
# Morningstar                          3
# Altair                               3
# Stama                                3
# Nautica Esposito                     3
# Mira                                 3
# Holland Stahlverdränger              3
# Diano                                3
# Veha                                 3
# Vacance                              3
# Cabo                                 3
# Doggersbank                          3
# Uttern                               3
# Whaly                                3
# Supra                                3
# Funcraft                             3
# Babro                                3
# Cramar                               3
# Fipa Italiana                        3
# Condor Yachting                      3
# Arkos                                3
# Chung Hwa                            3
# Tahoe                                3
# Cobra Yachts                         3
# Bryant Boats                         3
# Fletcher                             3
# Beachcraft                           3
# Grady White Boats                    3
# Bege                                 3
# Astor                                3
# Gropp                                3
# Vismara                              3
# Marhen                               2
# Monte Fino                           2
# Minor                                2
# Waterland                            2
# Monachus                             2
# Trawler                              2
# Magnum                               2
# MP Watersport                        2
# Costruzioni Navali Srl               2
# Corvette Cruisers                    2
# Mainship                             2
# Moonen                               2
# Enterprise Marine                    2
# Scanner                              2
# Comar                                2
# MBK                                  2
# Mery Nautic                          2
# Tony Giugliano                       2
# Mariah                               2
# Mazury                               2
# Maril                                2
# Dufour                               2
# Marina Brodersby                     2
# Axis                                 2
# Marine Offshore                      2
# Thermo Yacht                         2
# Ebbtide                              2
# Tigé                                 2
# Tristan                              2
# Ecoline                              2
# Marino                               2
# Haines                               2
# Schweizer                            2
# Egemar                               2
# Terra Nauta                          2
# WeiBo                                2
# Albin                                2
# Haber                                2
# Admiral                              2
# Sasga Yachts                         2
# Renken                               2
# Camuffo                              2
# VICEM                                2
# Pearl                                2
# AW                                   2
# Bugari                               2
# ARS Mare                             2
# Platinum                             2
# Viking (GB)                          2
# Viking Marin                         2
# Viknes                               2
# Triton                               2
# Viko                                 2
# Blu Martin                           2
# AM Yacht                             2
# Premiere Yacht                       2
# Blackfin                             2
# Privateer                            2
# Bimax                                2
# Vizianello                           2
# Beekmann                             2
# Overblue                             2
# Cantieri Navali di Livorno           2
# ZAR Formenti                         2
# Ocean Bay                            2
# Trojan                               2
# Yamaha                               2
# San Remo                             2
# Lund Boats                           2
# Neptunus Yachts                      2
# Nicols                               2
# Nireus                               2
# Tryvia                               2
# Salmeri Boote                        2
# Center Craft                         2
# Nordic                               2
# Adagio Yachts                        2
# Nordson                              2
# NorthMaster                          2
# Catarsi                              2
# Cascaruda                            2
# Numarine                             2
# SACS                                 2
# Ocean Alexander                      2
# Atlanta                              2
# Schweizer Bateaux                    2
# Intrepid                             2
# Holland Boat                         2
# Amberg                               2
# Hooveld                              2
# Super Lauwersmeer                    2
# Gibert Marine                        2
# Joda                                 2
# Johnson                              2
# Skilso                               2
# Flying Shark                         2
# Skagen                               2
# Karel                                2
# Giudecca                             2
# White Shark                          2
# Wicabo                               2
# Gouwerok                             2
# Horizon Yacht                        2
# Italmarine                           2
# Kimple                               2
# Staempfli                            2
# Hustler                              2
# Ibiza Boats                          2
# Idea Marine                          2
# Gallart                              2
# Amer                                 2
# Fratelli Aprea                       2
# Sport Craft                          2
# Symbol Yachts                        2
# Loon                                 2
# Garin                                2
# Invader                              2
# Windy Oceancraft                     2
# Spertini                             2
# Argo                                 2
# Stilecatalini                        2
# Futuro                               2
# Siemer                               2
# Heinrich                             2
# Haines Marine                        2
# 3B Craft                             2
# HT Houseboats                        2
# Eurobanker                           2
# Europe Marine                        2
# Euroship                             2
# Tecnomarine                          2
# Gulf Craft                           2
# FFW Sealver                          2
# Striker                              2
# Falcon Yachts                        2
# Lambro                               2
# La Mare                              2
# Heesen Yachts                        2
# Hellingskip                          2
# Koopmans                             2
# Grginic                              2
# Kramer                               2
# Shiren                               2
# Richard Dunston                      1
# Rohn                                 1
# Verus                                1
# Victoria                             1
# V2 Boats                             1
# Zeeland Jachtbouw                    1
# Vitech                               1
# Suncoast                             1
# Rayglass                             1
# Rodriguez Group (Italyachts)         1
# Volvo                                1
# Zeta Group                           1
# Starweld                             1
# van de Werf                          1
# Romar                                1
# Wider                                1
# Suncamper                            1
# Rose Island                          1
# Royal Denship                        1
# Wiking                               1
# Reinell                              1
# Unica Yacht                          1
# Voyager                              1
# Vertens                              1
# VEB                                  1
# Statement Marine                     1
# Rijo Kruiser                         1
# Stalder                              1
# Super Kaagkruiser                    1
# Viko Yachts                          1
# Rigiflex                             1
# Zuiderzee                            1
# Rijnkruiser                          1
# Valiant                              1
# Steilsteven                          1
# van Wijk                             1
# Viksund                              1
# Recla                                1
# Ventus                               1
# Vedette                              1
# Zodiac                               1
# VZ Cantiere Nautico                  1
# Vrijbuiter                           1
# VTS Boats                            1
# Williams                             1
# Riva Bertram                         1
# Verhoeven                            1
# Waddenkruiser                        1
# Stormer                              1
# Rivers and Tides                     1
# Zetacraft                            1
# Steiner                              1
# Ten Broeke                           1
# Wajer                                1
# Technohull                           1
# Scout Boats                          1
# Werner                               1
# Sigrist                              1
# Techno Yachts                        1
# Schwarz                              1
# Tinn-Silver                          1
# Silverline                           1
# Schottel                             1
# Titanium                             1
# Tjeukemer                            1
# Tauscheck                            1
# Schneiter                            1
# Tarquin                              1
# Schlosswerft                         1
# Witti                                1
# Ses Yachts                           1
# Sea Pro                              1
# UMS-Boat                             1
# Weidling                             1
# Searider                             1
# Sealver                              1
# Seagull                              1
# Teltow Werft                         1
# Tegernseer Bootsbau                  1
# Seacode                              1
# Seaco                                1
# Seebold                              1
# Selco                                1
# The Captains                         1
# Selje                                1
# Thompson                             1
# Sea Sprite                           1
# Thunderbird                          1
# Technus                              1
# Schaefer                             1
# Topaz                                1
# Webbcraft                            1
# Schachner                            1
# Sonic                                1
# Sossego                              1
# Yachtwerft Berlin                    1
# Saphire                              1
# Trophy                               1
# Waltjen                              1
# Z-Yacht                              1
# Walser                               1
# Sylvan Marine                        1
# Swordsman                            1
# Wake                                 1
# Westwind                             1
# Suzuki                               1
# Sabre                                1
# SBM                                  1
# Ta Yang                              1
# Saura                                1
# Solare                               1
# Slepsk                               1
# Tracker Marine                       1
# Targa                                1
# West Bay                             1
# Trader Motor Yachts                  1
# Skarpnes                             1
# Skilsö                               1
# Scar                                 1
# Yachting France                      1
# Winga                                1
# Tresfjord                            1
# Scandinavia                          1
# Yacht Service SP. z o.o.             1
# Smartboat                            1
# Waterdream                           1
# Ranger                               1
# 2 emme marine                        1
# Rancraft                             1
# Caravelle                            1
# Crestliner                           1
# Cox Marine                           1
# Couach                               1
# Concordia                            1
# Compromis                            1
# Colvic                               1
# Coaster                              1
# Cipax AS                             1
# Cigala & Bertinetti                  1
# Chrysler                             1
# Checkmate                            1
# Celebrity                            1
# Catfish                              1
# Carolina Classic                     1
# Cap Ferret                           1
# D-Boat                               1
# Cantieri Schiavone                   1
# Cantieri Navali Arno                 1
# Cantieri Nautici Solcio              1
# Cantieri Nautici Dalla Pieta         1
# Cantiere delle Marche                1
# Calcagno                             1
# Calafuria                            1
# CAD Marine                           1
# C.N. Tigullio                        1
# Burger                               1
# Buetzfleth                           1
# Bucher                               1
# Brunnert-Grimm                       1
# Brig                                 1
# Curvelle                             1
# Dacapo                               1
# Galaxy                               1
# Explorer                             1
# Freedom                              1
# Franchini                            1
# Fountain                             1
# Formula Cruisers                     1
# Forbina                              1
# Flevo                                1
# Fjord Plast                          1
# Finnlineboats                        1
# Fincantieri Yachts                   1
# Fidego                               1
# Fibramar                             1
# Feltz                                1
# Faul                                 1
# Fartes                               1
# Eurocrown                            1
# Dawncraft                            1
# Escape Sloepen                       1
# Ernst Riss                           1
# Erman Yachting                       1
# Envision                             1
# Egon Bredgaard                       1
# Ecofiber                             1
# EVO                                  1
# ERC                                  1
# Dynasty                              1
# Drettmann                            1
# Donzi                                1
# Doerak Sneek                         1
# De Wiel                              1
# De Vries                             1
# Bootbau Frei                         1
# Bond Yachts                          1
# Bombardier                           1
# Aegean Yachts                        1
# Aqualum                              1
# Aquabat                              1
# Anytec Boats                         1
# Anytec                               1
# Ancora                               1
# American Marine                      1
# Amerglass                            1
# Amel                                 1
# Aluminiumjon                         1
# AluVenture                           1
# Allround                             1
# Alen Yacht                           1
# Akerboom                             1
# Agder                                1
# Adventure                            1
# Bombard                              1
# Adler                                1
# Adex Nautica                         1
# Adec                                 1
# Acroplast                            1
# Acquaviva (IT)                       1
# Abeking & Rasmussen                  1
# Abati Yachts                         1
# AYROS                                1
# AW Yachts                            1
# ATOMIX                               1
# AMS Marine Yachten                   1
# AL Custom                            1
# AGA-Marine                           1
# AB Yachts                            1
# Aquarius                             1
# Aquaviva                             1
# Armee Suisse                         1
# Arp-Werft                            1
# Boatbuilding Academy Dorset          1
# Blumar                               1
# Bluline                              1
# Bluewater Yachts                     1
# Blue Sailors                         1
# Blue Ocean                           1
# Blue Navy                            1
# Blom                                 1
# Blohm + Voss                         1
# Blauwe Hand                          1
# Biot                                 1
# Bienchen                             1
# Best                                 1
# Bering Yachts                        1
# Bellcraft                            1
# Bazzerla                             1
# Barro                                1
# Baltic                               1
# Baha                                 1
# Baess                                1
# Back Cove                            1
# BWA                                  1
# BSC                                  1
# BM Nautica SRL                       1
# BLULINE (IT)                         1
# Azzurro                              1
# Ayros                                1
# Austin Parker                        1
# Astinor                              1
# GS Nautica                           1
# Gavazzi Luciano                      1
# Rampage                              1
# Myabca                               1
# Novurania                            1
# Northshore Yachts                    1
# Northern Marine                      1
# Nordmanns                            1
# Nord West                            1
# Nor-Dan                              1
# Nor Star                             1
# Need Yacht                           1
# Navalplastica                        1
# Navalia                              1
# Nautilus                             1
# Nautica                              1
# Nasbo                                1
# Nadirmarine                          1
# Motocraft                            1
# Nuova Jolly                          1
# Motiva                               1
# Moschini                             1
# Moonraker                            1
# Moonfleet                            1
# Mondo marine                         1
# Momenta                              1
# Mirage                               1
# Milan                                1
# Meridian Yachts                      1
# Meier                                1
# Maxi Dolphin                         1
# Martin                               1
# Marino Costruzioni Nautiche          1
# Marino CN                            1
# Numo                                 1
# Nussbaumer                           1
# GioMare                              1
# Pearlsea Yachts                      1
# Quicksilver Inflatables              1
# Queens Yachts                        1
# QErre                                1
# Q-Yachts                             1
# Prins van Oranje                     1
# Primeur                              1
# Premier                              1
# Pollini                              1
# Pollard                              1
# Poldijk Jachtbouw B.V.               1
# Poca                                 1
# Piantoni                             1
# Perini Navi Spa                      1
# Pegiva                               1
# Pavati                               1
# Ocea                                 1
# Parente                              1
# Paragon                              1
# Pantera                              1
# Palmer Johnson                       1
# PR Marine                            1
# Oyster                               1
# Ott Werft                            1
# Osprey                               1
# Orskov Skibsvaerft                   1
# Orca                                 1
# Oost                                 1
# Off-Course                           1
# Ockelbo                              1
# Ocean Yachts                         1
# Marine Yachting                      1
# Marine Pro                           1
# Marieholm                            1
# Hoekstra                             1
# Janmor                               1
# Jan Van Gent                         1
# Jaguar                               1
# J2J Service                          1
# Italversil                           1
# Island Gypsy                         1
# Interster                            1
# Interboat DE                         1
# Ibis                                 1
# ISA Yachts                           1
# IMP Boats                            1
# Hunton                               1
# Hunter                               1
# Hoya                                 1
# HoWa                                 1
# Marian                               1
# Hitzler-Werft Regensburg             1
# Hervé                                1
# Hensa                                1
# Hemiksem                             1
# Helstede                             1
# Hatecke                              1
# Hasler                               1
# Harris FloteBote                     1
# Hanto                                1
# Hans A. Deerberg                     1
# Hagenah                              1
# HI-Star                              1
# Graso                                1
# Glacer                               1
# Jans                                 1
# Javazzo                              1
# Johnson Yachts                       1
# Jongert                              1
# Marco Yachts                         1
# Mako Boats                           1
# Magic Yachts                         1
# MMS                                  1
# MAS                                  1
# Lütje                                1
# Lürssen Yachts                       1
# Lunde                                1
# Luhrs                                1
# Linden                               1
# Liberty                              1
# Lex Boats                            1
# Lengers                              1
# Leidi                                1
# Lavagna                              1
# Lamor                                1
# Kronborg Marine                      1
# Kraps                                1
# Knierim Yachtbau                     1
# Klase A                              1
# Kirie                                1
# Kiel Classic                         1
# Kempers                              1
# Kempala (NL)                         1
# Kapiteinssloep                       1
# Kammin                               1
# Kaasbøll                             1
# KOK                                  1
# Jouandoudet                          1
# Öchsner                              1
# dtype: int64

# %%
t = df['Type'].fillna('None').unique()
#sorted(t)
print(df.groupby('Type').size().sort_values(ascending = False))
# Out:
# Type
# Used boat,Diesel                4140
# Used boat,Unleaded              1686
# Used boat                       1462
# new boat from stock,Unleaded    1107
# new boat from stock              665
# new boat from stock,Diesel       291
# new boat on order,Unleaded       150
# Display Model,Unleaded            75
# new boat on order,Diesel          61
# new boat on order                 61
# Diesel                            57
# Used boat,Electric                27
# Unleaded                          22
# Display Model,Diesel              19
# Display Model                     18
# new boat from stock,Electric      18
# Used boat,Gas                     10
# Display Model,Electric             6
# new boat from stock,Gas            2
# Used boat,Propane                  1
# Electric                           1
# new boat from stock,Hybrid         1
# Display Model,Gas                  1
# Used boat,Hybrid                   1
# dtype: int64
